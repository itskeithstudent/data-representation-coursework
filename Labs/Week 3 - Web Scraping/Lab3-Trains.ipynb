# %%
import requests
import csv
from bs4 import BeautifulSoup

# %%
url =  "http://api.irishrail.ie/realtime/realtime.asmx/getCurrentTrainsXML"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'xml')
#print (soup.prettify())

# %%
listings = soup.findAll("objTrainPositions")
for listing in listings:
    print(listing)
    print(listing.TrainLatitude.string)
# Out:
# <objTrainPositions>
# <TrainStatus>N</TrainStatus>
# <TrainLatitude>51.9018</TrainLatitude>
# <TrainLongitude>-8.4582</TrainLongitude>
# <TrainCode>P258</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>P258\nCork to Mallow\nExpected Departure 22:00</PublicMessage>
# <Direction>To Mallow</Direction>
# </objTrainPositions>
# 51.9018
# <objTrainPositions>
# <TrainStatus>N</TrainStatus>
# <TrainLatitude>51.9212</TrainLatitude>
# <TrainLongitude>-8.17579</TrainLongitude>
# <TrainCode>P290</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>P290\nMidleton to Cork\nExpected Departure 21:45</PublicMessage>
# <Direction>To Cork</Direction>
# </objTrainPositions>
# 51.9212
# <objTrainPositions>
# <TrainStatus>N</TrainStatus>
# <TrainLatitude>53.2043</TrainLatitude>
# <TrainLongitude>-6.10046</TrainLongitude>
# <TrainCode>E947</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E947\nBray to Howth\nExpected Departure 22:00</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.2043
# <objTrainPositions>
# <TrainStatus>N</TrainStatus>
# <TrainLatitude>53.3891</TrainLatitude>
# <TrainLongitude>-6.07401</TrainLongitude>
# <TrainCode>E133</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E133\nHowth to Greystones\nExpected Departure 22:00</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>
# 53.3891
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>0</TrainLatitude>
# <TrainLongitude>0</TrainLongitude>
# <TrainCode>A226</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A226\n19:00 - Dublin Heuston to Cork (11 mins late)\nDeparted Killarney Junction next stop Cork</PublicMessage>
# <Direction>To Cork</Direction>
# </objTrainPositions>
# 0
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>0</TrainLatitude>
# <TrainLongitude>0</TrainLongitude>
# <TrainCode>A230</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A230\n21:00 - Dublin Heuston to Cork (-8 mins late)\nDeparted PL102 next stop Thurles</PublicMessage>
# <Direction>To Cork</Direction>
# </objTrainPositions>
# 0
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>0</TrainLatitude>
# <TrainLongitude>0</TrainLongitude>
# <TrainCode>A808</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A808\n18:15 - Dublin Heuston to Westport (17 mins late)\nDeparted Athlone Midland Yard next stop Roscommon</PublicMessage>
# <Direction>To Westport</Direction>
# </objTrainPositions>
# 0
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>52.1396</TrainLatitude>
# <TrainLongitude>-8.65521</TrainLongitude>
# <TrainCode>A314</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A314\n21:00 - Cork to Tralee (10 mins late)\nDeparted Mallow next stop Banteer</PublicMessage>
# <Direction>To Tralee</Direction>
# </objTrainPositions>
# 52.1396
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>52.6766</TrainLatitude>
# <TrainLongitude>-7.82189</TrainLongitude>
# <TrainCode>A231</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A231\n20:25 - Cork to Dublin Heuston (1 mins late)\nDeparted Thurles next stop Portlaoise</PublicMessage>
# <Direction>To Dublin Heuston</Direction>
# </objTrainPositions>
# 52.6766
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>52.992</TrainLatitude>
# <TrainLongitude>-6.9762</TrainLongitude>
# <TrainCode>A519</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A519\n21:36 - Carlow to Dublin Heuston (3 mins late)\nArrived Athy next stop Kildare</PublicMessage>
# <Direction>To Dublin Heuston</Direction>
# </objTrainPositions>
# 52.992
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.163</TrainLatitude>
# <TrainLongitude>-6.90802</TrainLongitude>
# <TrainCode>A229</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A229\n19:25 - Cork to Dublin Heuston (7 mins late)\nDeparted Kildare next stop Dublin Heuston</PublicMessage>
# <Direction>To Dublin Heuston</Direction>
# </objTrainPositions>
# 53.163
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.1855</TrainLatitude>
# <TrainLongitude>-6.80807</TrainLongitude>
# <TrainCode>D219</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>D219\n21:05 - Dublin Heuston to Portlaoise (4 mins late)\nDeparted Newbridge next stop Kildare</PublicMessage>
# <Direction>To Portlaoise</Direction>
# </objTrainPositions>
# 53.1855
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.2043</TrainLatitude>
# <TrainLongitude>-6.10046</TrainLongitude>
# <TrainCode>E130</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E130\n20:30 - Howth to Greystones (1 mins late)\nDeparted Bray next stop Greystones</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>
# 53.2043
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.2043</TrainLatitude>
# <TrainLongitude>-6.10046</TrainLongitude>
# <TrainCode>E846</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E846\n21:34 - Greystones to Malahide (4 mins late)\nDeparted Bray next stop Shankill</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.2043
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.2756</TrainLatitude>
# <TrainLongitude>-6.10333</TrainLongitude>
# <TrainCode>E259</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E259\n20:45 - Malahide to Bray (1 mins late)\nDeparted Dalkey next stop Killiney</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>
# 53.2756
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.2878</TrainLatitude>
# <TrainLongitude>-6.12712</TrainLongitude>
# <TrainCode>E946</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E946\n21:30 - Bray to Howth (2 mins late)\nDeparted Sandycove next stop Dun Laoghaire</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.2878
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.2991</TrainLatitude>
# <TrainLongitude>-6.16512</TrainLongitude>
# <TrainCode>E131</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E131\n21:00 - Howth to Greystones (0 mins late)\nArrived Seapoint next stop Salthill and Monkstown</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>
# 53.2991
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3015</TrainLatitude>
# <TrainLongitude>-8.74855</TrainLongitude>
# <TrainCode>A718</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A718\n19:35 - Dublin Heuston to Galway (3 mins late)\nDeparted Athenry next stop Oranmore</PublicMessage>
# <Direction>To Galway</Direction>
# </objTrainPositions>
# 53.3015
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3206</TrainLatitude>
# <TrainLongitude>-6.21112</TrainLongitude>
# <TrainCode>E845</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E845\n21:04 - Greystones to Malahide (2 mins late)\nDeparted Sydney Parade next stop Sandymount</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.3206
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.334</TrainLatitude>
# <TrainLongitude>-6.37868</TrainLongitude>
# <TrainCode>A719</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A719\n19:20 - Galway to Dublin Heuston (1 mins late)\nDeparted Park West and Cherry Orchard next stop Dublin Heuston</PublicMessage>
# <Direction>To Dublin Heuston</Direction>
# </objTrainPositions>
# 53.334
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.334</TrainLatitude>
# <TrainLongitude>-6.37868</TrainLongitude>
# <TrainCode>A809</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A809\n18:20 - Westport to Dublin Heuston (10 mins late)\nDeparted Park West and Cherry Orchard next stop Dublin Heuston</PublicMessage>
# <Direction>To Dublin Heuston</Direction>
# </objTrainPositions>
# 53.334
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.334</TrainLatitude>
# <TrainLongitude>-6.37868</TrainLongitude>
# <TrainCode>P221</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>P221\n20:33 - Portlaoise to Dublin Heuston (3 mins late)\nDeparted Park West and Cherry Orchard next stop Dublin Heuston</PublicMessage>
# <Direction>To Dublin Heuston</Direction>
# </objTrainPositions>
# 53.334
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.334</TrainLatitude>
# <TrainLongitude>-6.37868</TrainLongitude>
# <TrainCode>P421</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>P421\n21:35 - Hazelhatch to Grand Canal Dock (0 mins late)\nDeparted Park West and Cherry Orchard next stop Drumcondra</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.334
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3433</TrainLatitude>
# <TrainLongitude>-6.24829</TrainLongitude>
# <TrainCode>E260</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E260\n21:15 - Malahide to Bray (3 mins late)\nArrived Dublin Pearse next stop Grand Canal Dock</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>
# 53.3433
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3531</TrainLatitude>
# <TrainLongitude>-6.24591</TrainLongitude>
# <TrainCode>E945</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E945\n21:00 - Bray to Howth (0 mins late)\nArrived Dublin Connolly next stop Clontarf Road</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.3531
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3632</TrainLatitude>
# <TrainLongitude>-6.25908</TrainLongitude>
# <TrainCode>D422</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>D422\n21:30 - Grand Canal Dock to Hazelhatch (0 mins late)\nDeparted Drumcondra next stop Park West and Cherry Orchard</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>
# 53.3632
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3725</TrainLatitude>
# <TrainLongitude>-6.29869</TrainLongitude>
# <TrainCode>P680</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>P680\n21:07 - Maynooth to Dublin Pearse (9 mins late)\nDeparted Broombridge next stop Drumcondra</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>
# 53.3725
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.373</TrainLatitude>
# <TrainLongitude>-6.20442</TrainLongitude>
# <TrainCode>E132</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E132\n21:30 - Howth to Greystones (2 mins late)\nArrived Killester next stop Clontarf Road</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>
# 53.373
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3776</TrainLatitude>
# <TrainLongitude>-6.39072</TrainLongitude>
# <TrainCode>A915</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A915\n19:05 - Sligo to Dublin Connolly (4 mins late)\nArrived Coolmine next stop Drumcondra</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>
# 53.3776
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.378</TrainLatitude>
# <TrainLongitude>-6.58993</TrainLongitude>
# <TrainCode>D935</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>D935\n20:50 - Dublin Connolly to Mullingar (3 mins late)\nDeparted Maynooth next stop Kilcock</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.378
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3831</TrainLatitude>
# <TrainLongitude>-6.4242</TrainLongitude>
# <TrainCode>D319</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>D319\n21:45 - Clonsilla to M3 Parkway (4 mins late)\nDeparted Clonsilla next stop Hansfield</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.3831
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3831</TrainLatitude>
# <TrainLongitude>-6.4242</TrainLongitude>
# <TrainCode>D936</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>D936\n21:08 - Dublin Pearse to Maynooth (6 mins late)\nDeparted Clonsilla next stop Leixlip (Confey)</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.3831
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3909</TrainLatitude>
# <TrainLongitude>-6.15672</TrainLongitude>
# <TrainCode>D829</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>D829\n23:40 - Dublin Pearse to Dundalk (2 mins late)\nArrived Howth Junction next stop Clongriffin</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.3909
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3909</TrainLatitude>
# <TrainLongitude>-6.15672</TrainLongitude>
# <TrainCode>E844</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E844\n20:34 - Greystones to Malahide (1 mins late)\nDeparted Howth Junction next stop Clongriffin</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.3909
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.4169</TrainLatitude>
# <TrainLongitude>-6.1512</TrainLongitude>
# <TrainCode>P625</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>P625\n20:40 - Dundalk to Dublin Pearse (4 mins late)\nDeparted Portmarnock next stop Dublin Connolly</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>
# 53.4169
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.4509</TrainLatitude>
# <TrainLongitude>-6.15649</TrainLongitude>
# <TrainCode>E261</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E261\n21:45 - Malahide to Bray (4 mins late)\nDeparted Malahide next stop Portmarnock</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>
# 53.4509
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.6635</TrainLatitude>
# <TrainLongitude>-6.23271</TrainLongitude>
# <TrainCode>D826</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>D826\n20:50 - Dublin Pearse to Drogheda (10 mins late)\nArrived Mosney next stop Laytown</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.6635
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.712</TrainLatitude>
# <TrainLongitude>-6.33538</TrainLongitude>
# <TrainCode>A136</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A136\n20:50 - Dublin Connolly to Belfast (6 mins late)\nDeparted Drogheda next stop Dundalk</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.712
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.712</TrainLatitude>
# <TrainLongitude>-6.33538</TrainLongitude>
# <TrainCode>A143</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A143\n20:05 - Belfast to Dublin Connolly (3 mins late)\nDeparted Drogheda next stop Dublin Connolly</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>
# 53.712
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.712</TrainLatitude>
# <TrainLongitude>-6.33538</TrainLongitude>
# <TrainCode>P714</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>P714\n22:05 - Drogheda to Dublin Connolly (-76 mins late)\nDeparted Drogheda next stop Laytown</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>
# 53.712
# <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.9383</TrainLatitude>
# <TrainLongitude>-8.10657</TrainLongitude>
# <TrainCode>A914</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>A914\n19:17 - Dublin Connolly to Sligo (2 mins late)\nDeparted Carrick on Shannon next stop Boyle</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.9383
# <objTrainPositions>
# <TrainStatus>T</TrainStatus>
# <TrainLatitude>53.3891</TrainLatitude>
# <TrainLongitude>-6.07401</TrainLongitude>
# <TrainCode>E944</TrainCode>
# <TrainDate>03 Nov 2021</TrainDate>
# <PublicMessage>E944\n20:30 - Bray to Howth(0 mins late)\nTERMINATED Howth at 21:43</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>
# 53.3891

# %%
retrieveTags=['TrainStatus',
'TrainLatitude',
'TrainLongitude',
'TrainCode',
'TrainDate',
'PublicMessage',
'Direction'
]
with open('week03_train.csv', mode='w', newline='') as train_file:
    train_writer = csv.writer(train_file, delimiter='\t', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    listings = soup.findAll("objTrainPositions")
    for listing in listings:
        lat =float( listing.TrainLatitude.string)
        if (lat < 53.4):
            entryList = []
            for retrieveTag in retrieveTags:
                entryList.append(listing.find(retrieveTag).string)
                print(entryList)
            #entryList.append(listing.find('TrainLatitude').string)
            train_writer.writerow(entryList)
        else: print("YES")
# Out:
# ['N']
# ['N', '53.3831']
# ['N', '53.3831', '-6.4242']
# ['N', '53.3831', '-6.4242', 'D321']
# ['N', '53.3831', '-6.4242', 'D321', '07 Oct 2021']
# ['N', '53.3831', '-6.4242', 'D321', '07 Oct 2021', 'D321\\nClonsilla to M3 Parkway\\nExpected Departure 23:57']
# ['N', '53.3831', '-6.4242', 'D321', '07 Oct 2021', 'D321\\nClonsilla to M3 Parkway\\nExpected Departure 23:57', 'Northbound']
# ['N']
# ['N', '53.3891']
# ['N', '53.3891', '-6.07401']
# ['N', '53.3891', '-6.07401', 'E707']
# ['N', '53.3891', '-6.07401', 'E707', '07 Oct 2021']
# ['N', '53.3891', '-6.07401', 'E707', '07 Oct 2021', 'E707\\nHowth to Dublin Connolly\\nExpected Departure 23:55']
# ['N', '53.3891', '-6.07401', 'E707', '07 Oct 2021', 'E707\\nHowth to Dublin Connolly\\nExpected Departure 23:55', 'Southbound']
# ['R']
# ['R', '53.2043']
# ['R', '53.2043', '-6.10046']
# ['R', '53.2043', '-6.10046', 'E134']
# ['R', '53.2043', '-6.10046', 'E134', '07 Oct 2021']
# ['R', '53.2043', '-6.10046', 'E134', '07 Oct 2021', 'E134\\n22:30 - Howth to Greystones (-1 mins late)\\nDeparted Bray next stop Greystones']
# ['R', '53.2043', '-6.10046', 'E134', '07 Oct 2021', 'E134\\n22:30 - Howth to Greystones (-1 mins late)\\nDeparted Bray next stop Greystones', 'Southbound']
# ['R']
# ['R', '53.2469']
# ['R', '53.2469', '-6.66386']
# ['R', '53.2469', '-6.66386', 'D221']
# ['R', '53.2469', '-6.66386', 'D221', '07 Oct 2021']
# ['R', '53.2469', '-6.66386', 'D221', '07 Oct 2021', 'D221\\n23:10 - Dublin Heuston to Kildare (3 mins late)\\nDeparted Sallins next stop Newbridge']
# ['R', '53.2469', '-6.66386', 'D221', '07 Oct 2021', 'D221\\n23:10 - Dublin Heuston to Kildare (3 mins late)\\nDeparted Sallins next stop Newbridge', 'To Kildare']
# ['R']
# ['R', '53.2756']
# ['R', '53.2756', '-6.10333']
# ['R', '53.2756', '-6.10333', 'E263']
# ['R', '53.2756', '-6.10333', 'E263', '07 Oct 2021']
# ['R', '53.2756', '-6.10333', 'E263', '07 Oct 2021', 'E263\\n22:48 - Malahide to Bray (0 mins late)\\nArrived Dalkey next stop Killiney']
# ['R', '53.2756', '-6.10333', 'E263', '07 Oct 2021', 'E263\\n22:48 - Malahide to Bray (0 mins late)\\nArrived Dalkey next stop Killiney', 'Southbound']
# ['R']
# ['R', '53.3206']
# ['R', '53.3206', '-6.21112']
# ['R', '53.3206', '-6.21112', 'E135']
# ['R', '53.3206', '-6.21112', 'E135', '07 Oct 2021']
# ['R', '53.3206', '-6.21112', 'E135', '07 Oct 2021', 'E135\\n23:05 - Howth to Greystones (1 mins late)\\nArrived Sydney Parade next stop Booterstown']
# ['R', '53.3206', '-6.21112', 'E135', '07 Oct 2021', 'E135\\n23:05 - Howth to Greystones (1 mins late)\\nArrived Sydney Parade next stop Booterstown', 'Southbound']
# ['R']
# ['R', '53.3206']
# ['R', '53.3206', '-6.21112']
# ['R', '53.3206', '-6.21112', 'E703']
# ['R', '53.3206', '-6.21112', 'E703', '07 Oct 2021']
# ['R', '53.3206', '-6.21112', 'E703', '07 Oct 2021', 'E703\\n23:04 - Greystones to Dublin Connolly (2 mins late)\\nArrived Sydney Parade next stop Sandymount']
# ['R', '53.3206', '-6.21112', 'E703', '07 Oct 2021', 'E703\\n23:04 - Greystones to Dublin Connolly (2 mins late)\\nArrived Sydney Parade next stop Sandymount', 'Northbound']
# ['R']
# ['R', '53.334']
# ['R', '53.334', '-6.37868']
# ['R', '53.334', '-6.37868', 'P225']
# ['R', '53.334', '-6.37868', 'P225', '07 Oct 2021']
# ['R', '53.334', '-6.37868', 'P225', '07 Oct 2021', 'P225\\n22:30 - Portlaoise to Dublin Heuston (15 mins late)\\nDeparted Park West and Cherry Orchard next stop Dublin Heuston']
# ['R', '53.334', '-6.37868', 'P225', '07 Oct 2021', 'P225\\n22:30 - Portlaoise to Dublin Heuston (15 mins late)\\nDeparted Park West and Cherry Orchard next stop Dublin Heuston', 'To Dublin Heuston']
# ['R']
# ['R', '53.347']
# ['R', '53.347', '-6.25425']
# ['R', '53.347', '-6.25425', 'E949']
# ['R', '53.347', '-6.25425', 'E949', '07 Oct 2021']
# ['R', '53.347', '-6.25425', 'E949', '07 Oct 2021', 'E949\\n23:00 - Bray to Howth (0 mins late)\\nDeparted Tara Street next stop Dublin Connolly']
# ['R', '53.347', '-6.25425', 'E949', '07 Oct 2021', 'E949\\n23:00 - Bray to Howth (0 mins late)\\nDeparted Tara Street next stop Dublin Connolly', 'Northbound']
# ['R']
# ['R', '53.3531']
# ['R', '53.3531', '-6.24591']
# ['R', '53.3531', '-6.24591', 'D829']
# ['R', '53.3531', '-6.24591', 'D829', '07 Oct 2021']
# ['R', '53.3531', '-6.24591', 'D829', '07 Oct 2021', 'D829\\n23:40 - Dublin Pearse to Dundalk (1 mins late)\\nDeparted Dublin Connolly next stop Howth Junction']
# ['R', '53.3531', '-6.24591', 'D829', '07 Oct 2021', 'D829\\n23:40 - Dublin Pearse to Dundalk (1 mins late)\\nDeparted Dublin Connolly next stop Howth Junction', 'Northbound']
# ['R']
# ['R', '53.3632']
# ['R', '53.3632', '-6.25908']
# ['R', '53.3632', '-6.25908', 'D424']
# ['R', '53.3632', '-6.25908', 'D424', '07 Oct 2021']
# ['R', '53.3632', '-6.25908', 'D424', '07 Oct 2021', 'D424\\n23:22 - Grand Canal Dock to Hazelhatch (3 mins late)\\nDeparted Drumcondra next stop Park West and Cherry Orchard']
# ['R', '53.3632', '-6.25908', 'D424', '07 Oct 2021', 'D424\\n23:22 - Grand Canal Dock to Hazelhatch (3 mins late)\\nDeparted Drumcondra next stop Park West and Cherry Orchard', 'Southbound']
# ['R']
# ['R', '53.3725']
# ['R', '53.3725', '-6.29869']
# ['R', '53.3725', '-6.29869', 'P766']
# ['R', '53.3725', '-6.29869', 'P766', '07 Oct 2021']
# ['R', '53.3725', '-6.29869', 'P766', '07 Oct 2021', 'P766\\n23:10 - Maynooth to Dublin Connolly (2 mins late)\\nArrived Broombridge next stop Drumcondra']
# ['R', '53.3725', '-6.29869', 'P766', '07 Oct 2021', 'P766\\n23:10 - Maynooth to Dublin Connolly (2 mins late)\\nArrived Broombridge next stop Drumcondra', 'Southbound']
# ['R']
# ['R', '53.373']
# ['R', '53.373', '-6.20442']
# ['R', '53.373', '-6.20442', 'E705']
# ['R', '53.373', '-6.20442', 'E705', '07 Oct 2021']
# ['R', '53.373', '-6.20442', 'E705', '07 Oct 2021', 'E705\\n23:30 - Howth to Dublin Connolly (0 mins late)\\nArrived Killester next stop Clontarf Road']
# ['R', '53.373', '-6.20442', 'E705', '07 Oct 2021', 'E705\\n23:30 - Howth to Dublin Connolly (0 mins late)\\nArrived Killester next stop Clontarf Road', 'Southbound']
# ['R']
# ['R', '53.3816']
# ['R', '53.3816', '-6.37149']
# ['R', '53.3816', '-6.37149', 'D938']
# ['R', '53.3816', '-6.37149', 'D938', '07 Oct 2021']
# ['R', '53.3816', '-6.37149', 'D938', '07 Oct 2021', 'D938\\n23:20 - Dublin Pearse to Maynooth (0 mins late)\\nArrived Castleknock next stop Coolmine']
# ['R', '53.3816', '-6.37149', 'D938', '07 Oct 2021', 'D938\\n23:20 - Dublin Pearse to Maynooth (0 mins late)\\nArrived Castleknock next stop Coolmine', 'Northbound']
# ['R']
# ['R', '53.387']
# ['R', '53.387', '-6.16163']
# ['R', '53.387', '-6.16163', 'E848']
# ['R', '53.387', '-6.16163', 'E848', '07 Oct 2021']
# ['R', '53.387', '-6.16163', 'E848', '07 Oct 2021', 'E848\\n22:34 - Greystones to Malahide (0 mins late)\\nArrived Kilbarrack next stop Howth Junction']
# ['R', '53.387', '-6.16163', 'E848', '07 Oct 2021', 'E848\\n22:34 - Greystones to Malahide (0 mins late)\\nArrived Kilbarrack next stop Howth Junction', 'Northbound']
# YES
# YES
# ['T']
# ['T', '53.3531']
# ['T', '53.3531', '-6.24591']
# ['T', '53.3531', '-6.24591', 'E704']
# ['T', '53.3531', '-6.24591', 'E704', '07 Oct 2021']
# ['T', '53.3531', '-6.24591', 'E704', '07 Oct 2021', 'E704\\n23:17 - Malahide to Dublin Connolly(-2 mins late)\\nTERMINATED Dublin Connolly at 23:39']
# ['T', '53.3531', '-6.24591', 'E704', '07 Oct 2021', 'E704\\n23:17 - Malahide to Dublin Connolly(-2 mins late)\\nTERMINATED Dublin Connolly at 23:39', 'Southbound']
# ['T']
# ['T', '53.3891']
# ['T', '53.3891', '-6.07401']
# ['T', '53.3891', '-6.07401', 'E948']
# ['T', '53.3891', '-6.07401', 'E948', '07 Oct 2021']
# ['T', '53.3891', '-6.07401', 'E948', '07 Oct 2021', 'E948\\n22:30 - Bray to Howth(1 mins late)\\nTERMINATED Howth at 23:46']
# ['T', '53.3891', '-6.07401', 'E948', '07 Oct 2021', 'E948\\n22:30 - Bray to Howth(1 mins late)\\nTERMINATED Howth at 23:46', 'Northbound']

# %%
print(listings)
# Out:
# [<objTrainPositions>
# <TrainStatus>N</TrainStatus>
# <TrainLatitude>53.3831</TrainLatitude>
# <TrainLongitude>-6.4242</TrainLongitude>
# <TrainCode>D321</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>D321\nClonsilla to M3 Parkway\nExpected Departure 23:57</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>N</TrainStatus>
# <TrainLatitude>53.3891</TrainLatitude>
# <TrainLongitude>-6.07401</TrainLongitude>
# <TrainCode>E707</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>E707\nHowth to Dublin Connolly\nExpected Departure 23:55</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.2043</TrainLatitude>
# <TrainLongitude>-6.10046</TrainLongitude>
# <TrainCode>E134</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>E134\n22:30 - Howth to Greystones (-1 mins late)\nDeparted Bray next stop Greystones</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.2469</TrainLatitude>
# <TrainLongitude>-6.66386</TrainLongitude>
# <TrainCode>D221</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>D221\n23:10 - Dublin Heuston to Kildare (3 mins late)\nDeparted Sallins next stop Newbridge</PublicMessage>
# <Direction>To Kildare</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.2756</TrainLatitude>
# <TrainLongitude>-6.10333</TrainLongitude>
# <TrainCode>E263</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>E263\n22:48 - Malahide to Bray (0 mins late)\nArrived Dalkey next stop Killiney</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3206</TrainLatitude>
# <TrainLongitude>-6.21112</TrainLongitude>
# <TrainCode>E135</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>E135\n23:05 - Howth to Greystones (1 mins late)\nArrived Sydney Parade next stop Booterstown</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3206</TrainLatitude>
# <TrainLongitude>-6.21112</TrainLongitude>
# <TrainCode>E703</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>E703\n23:04 - Greystones to Dublin Connolly (2 mins late)\nArrived Sydney Parade next stop Sandymount</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.334</TrainLatitude>
# <TrainLongitude>-6.37868</TrainLongitude>
# <TrainCode>P225</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>P225\n22:30 - Portlaoise to Dublin Heuston (15 mins late)\nDeparted Park West and Cherry Orchard next stop Dublin Heuston</PublicMessage>
# <Direction>To Dublin Heuston</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.347</TrainLatitude>
# <TrainLongitude>-6.25425</TrainLongitude>
# <TrainCode>E949</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>E949\n23:00 - Bray to Howth (0 mins late)\nDeparted Tara Street next stop Dublin Connolly</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3531</TrainLatitude>
# <TrainLongitude>-6.24591</TrainLongitude>
# <TrainCode>D829</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>D829\n23:40 - Dublin Pearse to Dundalk (1 mins late)\nDeparted Dublin Connolly next stop Howth Junction</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3632</TrainLatitude>
# <TrainLongitude>-6.25908</TrainLongitude>
# <TrainCode>D424</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>D424\n23:22 - Grand Canal Dock to Hazelhatch (3 mins late)\nDeparted Drumcondra next stop Park West and Cherry Orchard</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3725</TrainLatitude>
# <TrainLongitude>-6.29869</TrainLongitude>
# <TrainCode>P766</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>P766\n23:10 - Maynooth to Dublin Connolly (2 mins late)\nArrived Broombridge next stop Drumcondra</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.373</TrainLatitude>
# <TrainLongitude>-6.20442</TrainLongitude>
# <TrainCode>E705</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>E705\n23:30 - Howth to Dublin Connolly (0 mins late)\nArrived Killester next stop Clontarf Road</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.3816</TrainLatitude>
# <TrainLongitude>-6.37149</TrainLongitude>
# <TrainCode>D938</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>D938\n23:20 - Dublin Pearse to Maynooth (0 mins late)\nArrived Castleknock next stop Coolmine</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.387</TrainLatitude>
# <TrainLongitude>-6.16163</TrainLongitude>
# <TrainCode>E848</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>E848\n22:34 - Greystones to Malahide (0 mins late)\nArrived Kilbarrack next stop Howth Junction</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.4032</TrainLatitude>
# <TrainLongitude>-6.14839</TrainLongitude>
# <TrainCode>E706</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>E706\n23:40 - Malahide to Dublin Connolly (1 mins late)\nArrived Clongriffin next stop Howth Junction</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>R</TrainStatus>
# <TrainLatitude>53.712</TrainLatitude>
# <TrainLongitude>-6.33538</TrainLongitude>
# <TrainCode>D828</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>D828\n22:40 - Dublin Pearse to Dundalk (0 mins late)\nDeparted Drogheda next stop Dundalk</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>T</TrainStatus>
# <TrainLatitude>53.3531</TrainLatitude>
# <TrainLongitude>-6.24591</TrainLongitude>
# <TrainCode>E704</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>E704\n23:17 - Malahide to Dublin Connolly(-2 mins late)\nTERMINATED Dublin Connolly at 23:39</PublicMessage>
# <Direction>Southbound</Direction>
# </objTrainPositions>, <objTrainPositions>
# <TrainStatus>T</TrainStatus>
# <TrainLatitude>53.3891</TrainLatitude>
# <TrainLongitude>-6.07401</TrainLongitude>
# <TrainCode>E948</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>E948\n22:30 - Bray to Howth(1 mins late)\nTERMINATED Howth at 23:46</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>]

# %%
print(listings[0])
# Out:
# <objTrainPositions>
# <TrainStatus>N</TrainStatus>
# <TrainLatitude>53.3831</TrainLatitude>
# <TrainLongitude>-6.4242</TrainLongitude>
# <TrainCode>D321</TrainCode>
# <TrainDate>07 Oct 2021</TrainDate>
# <PublicMessage>D321\nClonsilla to M3 Parkway\nExpected Departure 23:57</PublicMessage>
# <Direction>Northbound</Direction>
# </objTrainPositions>

# %%
import csv

employee_file = open('employee_file.csv', mode='w')
employee_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

employee_writer.writerow(['John Smith','Accounting','November'])
employee_writer.writerow(['Erica Meyers','IT','March'])

employee_file.close()
