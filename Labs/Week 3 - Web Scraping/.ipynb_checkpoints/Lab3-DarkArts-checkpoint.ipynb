# %%
import requests 
from bs4 import BeautifulSoup

# %%
##Test to make sure we can send GET request
page = requests.get("http://dataquestio.github.io/web-scraping-pages/simple.html") 
print (page) 
print("-------------------") 
print (page.content)
# Out:
# <Response [200]>
# -------------------
# b'<!DOCTYPE html>\n<html>\n    <head>\n        <title>A simple example page</title>\n    </head>\n    <body>\n        <p>Here is some simple content for this page.</p>\n    </body>\n</html>'

# %% [markdown]
# Same as above but this time view what is returned from requsts.get a bit nicer using BeautifulSoup

# %%
page = requests.get("http://dataquestio.github.io/web-scraping-pages/simple.html") 
print (page) 
print("-------------------") 
print (page.content) 
soup1 = BeautifulSoup(page.content, 'html.parser') 
print("-------------------") 
print (soup1.prettify())
# Out:
# <Response [200]>
# -------------------
# b'<!DOCTYPE html>\n<html>\n    <head>\n        <title>A simple example page</title>\n    </head>\n    <body>\n        <p>Here is some simple content for this page.</p>\n    </body>\n</html>'
# -------------------
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    A simple example page
#   </title>
#  </head>
#  <body>
#   <p>
#    Here is some simple content for this page.
#   </p>
#  </body>
# </html>

# %%
with open("../Week 2 - Javascript/lab2.html") as fp: 
    soup = BeautifulSoup(fp,'html.parser') 
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    View Cars
#   </title>
#   <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" rel="stylesheet"/>
#  </head>
#  <body>
#   <h1>
#    Cars
#   </h1>
#   <div name="butt-div">
#    <button id="show-create-button" onclick="showCreate()">
#     Create
#    </button>
#   </div>
#   <div class="table" name="table-div">
#    <h2>
#     All Cars
#    </h2>
#    <table border="2" id="car-table" name="table">
#     <tr>
#      <th>
#       reg
#      </th>
#      <th>
#       make
#      </th>
#      <th>
#       model
#      </th>
#      <th>
#       price
#      </th>
#      <th>
#       Update
#      </th>
#      <th>
#       Delete
#      </th>
#     </tr>
#     <tr id="191 MO 123">
#      <td>
#       191 MO 123
#      </td>
#      <td>
#       Ford
#      </td>
#      <td>
#       Modeo
#      </td>
#      <td>
#       25000
#      </td>
#      <td>
#       <button onclick="showUpdate(this)">
#        update
#       </button>
#      </td>
#      <td>
#       <button onclick="doDelete(this)">
#        Delete
#       </button>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <div id="cu-form" name="form-div" style="display:none">
#    <h2>
#     <span id="create-label">
#      Create a
#     </span>
#     <span id="update-label">
#      Update this
#     </span>
#     Car
#    </h2>
#    Reg
#    <input name="reg" type="text"/>
#    <br/>
#    Make
#    <select name="make">
#     <option value="Ford">
#      Ford
#     </option>
#     <option value="Fiat">
#      Fiat
#     </option>
#     <option value="Nissan">
#      Nissan
#     </option>
#    </select>
#    <br/>
#    Model
#    <input name="model" type="text"/>
#    <br/>
#    Price
#    <input name="price" type="number"/>
#    <br/>
#    <span>
#     <button id="do-create-btn" onclick="doCreate()">
#      Create
#     </button>
#    </span>
#    <span>
#     <button id="do-update-btn" onclick="doUpdate()">
#      Update
#     </button>
#    </span>
#   </div>
#  </body>
#  <script>
#   //On click of create button at top of page hide table and other elements and make form visible
# 		//we want essentially the form to pop in and the tabular data to dissapear to behave like a user wants to add an entry
# 		function showCreate(){
#
# 			document.getElementById("show-create-button").style.display="none";
# 			document.getElementById("car-table").style.display="none";
# 			document.getElementById("cu-form").style.display="block"; //make form visible
#
# 			document.getElementById('create-label').style.display="inline" //make span visible
# 			document.getElementById('update-label').style.display="none"
#
# 			document.getElementById('do-create-btn').style.display="block" //make create button visible
# 			document.getElementById('do-update-btn').style.display="none"
# 		}
#
# 		//function to display back the table and hide the form
# 		function showViewAll(){
# 			document.getElementById("show-create-button").style.display="block";
# 			document.getElementById("car-table").style.display="block";
# 			document.getElementById("cu-form").style.display="none";
# 		}
#
# 		//function to clear up inputs to the form
# 		function clearForm(){
# 			var form = document.getElementById("cu-form");
# 			form.querySelector('input[name="reg"]').value ='';
# 			form.querySelector('select[name="make"]').value='';
# 			form.querySelector('input[name="model"]').value='';
# 			form.querySelector('input[name="price"]').value='';
# 		}
#
# 		//function to add a new entry to table element, takes in a json object as it's argument
# 		function addCarToTable(car){
# 			var table = document.getElementById('car-table'); //grab the table to insert data to
# 			var row = table.insertRow(-1); //append row to end of table
# 			row.setAttribute('id', car.reg);
# 			var cell0 = row.insertCell(0);
# 			console.log("here");
# 			cell0.innerHTML = car.reg;
# 			console.log(cell0);
# 			var cell1 = row.insertCell(1);
# 			cell1.innerHTML = car.make;
# 			var cell2 = row.insertCell(2);
# 			cell2.innerHTML = car.model;
# 			var cell3 = row.insertCell(3);
# 			cell3.innerHTML = car.price;
# 			var cell3 = row.insertCell(4);
# 			cell3.innerHTML = '<td><button onclick="showUpdate(this)">update</button></td>'
# 			var cell3 = row.insertCell(5);
# 			cell3.innerHTML = '<td><button onclick="doDelete(this)">Delete</button></td>'
#
# 		}
#
# 		//on click of create button from form, populate data in form back to table, creating a new row in process, clearing the form and showing back the table
# 		function doCreate(){
# 			var car = {};
# 			var form = document.getElementById("cu-form");
# 			car.reg = form.querySelector('input[name="reg"]').value
# 			car.make = form.querySelector('select[name="make"]').value;
# 			car.model = form.querySelector('input[name="model"]').value;
# 			car.price = form.querySelector('input[name="price"]').value;
# 			//console.log(car)
# 			addCarToTable(car);
# 			clearForm();
# 			showViewAll();
# 		}
#
# 		function getCarFromElement(row_ele){
# 			var car ={};
# 			car.reg = row_ele.cells[0].firstChild.textContent;
# 			car.make = row_ele.cells[1].firstChild.textContent;
# 			car.model = row_ele.cells[2].firstChild.textContent;
# 			car.price = row_ele.cells[3].firstChild.textContent;
# 			return car;
# 		}
#
# 		function popFormWithCar(car){
# 			var form = document.getElementById("cu-form");
# 			form.querySelector('input[name="reg"]').value = car.reg;
# 			form.querySelector('select[name="make"]').value= car.make;
# 			form.querySelector('input[name="model"]').value= car.model;
# 			form.querySelector('input[name="price"]').value=car.price;
# 		}
#
# 		function getCarFromForm(){
# 			var form = document.getElementById("cu-form");
# 			var car = {};
# 			car.reg = form.querySelector('input[name="reg"]').disabled = true;
# 			car.reg = form.querySelector('input[name="reg"]').value;
# 			car.make = form.querySelector('select[name="make"]').value;
# 			car.model = form.querySelector('input[name="model"]').value;
# 			car.price = form.querySelector('input[name="price"]').value;
# 			return car;
# 		}
#
# 		function updateCarInRow(row_ele, car){
# 			console.log(row_ele);
# 			row_ele.cells[0].firstChild.textContent = car.reg;
# 			row_ele.cells[1].firstChild.textContent = car.make;
# 			row_ele.cells[2].firstChild.textContent = car.model;
# 			row_ele.cells[3].firstChild.textContent = car.price;
# 		}
#
# 		//add skeleton function for performing same as doCreate but on updating a existing row
# 		function doUpdate(){
# 			var car = getCarFromForm();
# 			var row_ele = document.getElementById(car.reg);
# 			updateCarInRow(row_ele,car);
# 			clearForm();
# 			showViewAll();
# 		}
#
# 		//skeleton function to show when user wants to update a row
# 		function showUpdate(button_ele){
# 			document.getElementById("show-create-button").style.display="none";
# 			document.getElementById("car-table").style.display="none";
# 			document.getElementById("cu-form").style.display="block"; //make form visible
#
# 			document.getElementById('create-label').style.display="none" //make span invisible
# 			document.getElementById('update-label').style.display="inline"
#
# 			document.getElementById('do-create-btn').style.display="inline" //make create button invisible
# 			document.getElementById('do-update-btn').style.display="inline"
# 			var row_ele = button_ele.parentNode.parentNode;
# 			var car = getCarFromElement(row_ele);
# 			popFormWithCar(car);
# 		}
#
# 		function doDelete(button_ele){
# 			var row_ele = button_ele.parentNode.parentNode;
# 			var row_ele_index = row_ele.rowIndex;
#
# 			var table_ele = document.getElementById('car-table');
#
# 			table_ele.deleteRow(row_ele_index);
# 		}
#  </script>
# </html>

# %% [markdown]
# # Reading data from the HTML file
# Extract a tr tag (table row) from the html file

# %%
row = soup.find("tr")
print(row)
# Out:
# <tr>
# <th>reg</th>
# <th>make</th>
# <th>model</th>
# <th>price</th>
# <th>Update</th>
# <th>Delete</th>
# </tr>

# %% [markdown]
# That gave us the first row which contains table headers, but we want all rows

# %%
rows = soup.findAll("tr")
print(rows)
# Out:
# [<tr>
# <th>reg</th>
# <th>make</th>
# <th>model</th>
# <th>price</th>
# <th>Update</th>
# <th>Delete</th>
# </tr>, <tr id="191 MO 123">
# <td>191 MO 123</td>
# <td>Ford</td>
# <td>Modeo</td>
# <td>25000</td>
# <td><button onclick="showUpdate(this)">update</button></td>
# <td><button onclick="doDelete(this)">Delete</button></td>
# </tr>]

# %% [markdown]
# Now with findall we get a list of row's, I was lazy in my previous lab's table definition and only gave it two rows

# %%
#loop through each row, get td data and print it
#this will ignore th tag
for row in rows:
    cols = row.findAll("td")
    for col in cols:
        print(col.text)
# Out:
# 191 MO 123
# Ford
# Modeo
# 25000
# update
# Delete

# %%
dataList = []
for row in rows:
    cols = row.findAll("td")
    for col in cols:
        dataList.append(col.text)

print(dataList)
# Out:
# ['191 MO 123', 'Ford', 'Modeo', '25000', 'update', 'Delete']

# %% [markdown]
# Bit of messing around to get a csv file writer up and running

# %%
#write to a csv file
import csv

with open('employee_file.csv', mode='w', newline='') as employee_file:
    employee_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting = csv.QUOTE_MINIMAL)

    employee_writer.writerow(['john smith', 'Acc', 'Nov'])
    employee_writer.writerow(['Jane Doe', 'Cca', 'Nov'])

# %% [markdown]
# # Tie the bits together

# %%
#open the url using beautifulSoup html.parsr
with open("../Week 2 - Javascript/lab2.html") as fp: 
    soup = BeautifulSoup(fp,'html.parser') 
    
#Open csv file to write to it (creates new if not exists)
with open('week02data.csv', mode='w', newline='') as employee_file:
    employee_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting = csv.QUOTE_MINIMAL)
    #findall rows with tr tag
    rows = soup.findAll("tr")
    for row in rows:
        dataList=[] #list object to hold all text in td tags
        cols = row.findAll("td")
        for col in cols:
            #if col has button in it don't add to list
            if not col.find("button"):
                dataList.append(col.text)
        #write to csv if list not empty
        if dataList:
            #write list to csv once have looped through every column
            employee_writer.writerow(dataList)
        #continue loop across all rows

# %% [markdown]
# # Some Dark Arts

# %%
page = requests.get("https://www.myhome.ie/residential/mayo/property-for-sale?page=1") 
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script charset="UTF-8" src="https://cdn.cookielaw.org/consent/tcf.stub.js" type="text/javascript">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="GRSUae1sJQQCNp94-ItYu1akWObFD1cFkmd_OG30vgU" name="google-site-verification"/>
#   <title>
#    Residential property for sale in Mayo - MyHome.ie
#   </title>
#   <base href="/"/>
#   <meta name="robots"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <!-- Chrome, Firefox OS and Opera -->
#   <meta content="#009cdb" name="theme-color"/>
#   <!-- Windows Phone -->
#   <meta content="#009cdb" name="msapplication-navbutton-color"/>
#   <!-- iOS Safari -->
#   <meta content="#009cdb" name="apple-mobile-web-app-status-bar-style"/>
#   <link href="manifest.json" rel="manifest"/>
#   <meta content="width=device-width, minimum-scale=1.0, maximum-scale=5.0" name="viewport"/>
#   <!-- <meta name="fragment" content="!"> -->
#   <link href="favicon.ico" rel="icon" type="image/x-icon"/>
#   <!-- Google Tag Manager dataLayer -->
#   <!-- End Google Tag Manager dataLayer -->
#   <!-- doubleclick -->
#   <!-- IOS Icon additions -->
#   <meta content="no" name="apple-mobile-web-app-capable"/>
#   <link href="/src/assets/icons/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="/src/assets/images/splash-logos/apple-touch-startup/apple_splash_2048.png" rel="apple-touch-startup-image" sizes="2048x2732"/>
#   <link href="/src/assets/images/splash-logos/apple-touch-startup/apple_splash_1668.png" rel="apple-touch-startup-image" sizes="1668x2224"/>
#   <link href="/src/assets/images/splash-logos/apple-touch-startup/apple_splash_1536.png" rel="apple-touch-startup-image" sizes="1536x2048"/>
#   <link href="/src/assets/images/splash-logos/apple-touch-startup/apple_splash_1125.png" rel="apple-touch-startup-image" sizes="1125x2436"/>
#   <link href="/src/assets/images/splash-logos/apple-touch-startup/apple_splash_1242.png" rel="apple-touch-startup-image" sizes="1242x2208"/>
#   <link href="/src/assets/images/splash-logos/apple-touch-startup/apple_splash_750.png" rel="apple-touch-startup-image" sizes="750x1334"/>
#   <link href="/src/assets/images/splash-logos/apple-touch-startup/apple_splash_640.png" rel="apple-touch-startup-image" sizes="640x1136"/>
#   <script async="" defer="" src="https://maps.googleapis.com/maps/api/js?key=AIzaSyB20lC1dW9C6p2XxqY93BMdgbafZC8yv9g&amp;libraries=places,geometry">
#   </script>
#   <noscript>
#    <style>
#     .TransitionOverlay {
#         display: none !important;
#       }
#
#       .DesktopHeader__NavItem>.dropdown-menu {
#         display: block;
#       }
#    </style>
#   </noscript>
#   <meta content="#1976d2" name="theme-color"/>
#   <!-- Facebook Pixel Code -->
#   <script class="optanon-category-C0002-C0004" type="text/plain">
#    !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window,document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '734210737333726');
#     fbq('track', 'PageView');
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=734210737333726&amp;ev=PageView
#     &amp;noscript=1" width="1"/>
#   </noscript>
#   <!-- End Facebook Pixel Code -->
#   <!-- Preload LCP image -->
#   <link as="image" href="./assets/images/cottage.webp" rel="preload"/>
#   <link crossorigin="anonymous" href="styles.d983b1c002a6c7edc959.css" integrity="sha384-/vmV6qBxrXPWsJSv+A/OhKhIShDZNxZYJcxA8RTVpliyvsOMn3qRsuGN+rcxdtIc" rel="stylesheet"/>
#   <style ng-transition="myhome.ie">
#    .MhView{min-height:600px}mat-sidenav{background:#fff!important;width:55%!important;position:fixed!important;overflow-x:hidden!important}@media (max-width:750px){mat-sidenav{width:90%!important}}.disableContent{opacity:.2;pointer-events:none}.mat-drawer-container{position:unset!important}.watchlist{z-index:1;position:fixed;background:#009cdb;top:50%;right:0;padding:20px 0;transform:translateY(-50%);border-radius:30px 0 0 30px}fa-icon{color:#fff;padding:0 5px;font-size:1.2em}
#   </style>
#   <style ng-transition="myhome.ie">
#    .TransitionOverlay{position:fixed;width:100%;height:100%;top:0;left:0;background:#fff;z-index:1000;display:flex;justify-content:center;align-items:center}.TransitionOverlay__Image{animation:fadein 1s ease 0s 1 normal forwards;animation-iteration-count:infinite}@keyframes fadein{0%{opacity:0}50%{opacity:.5}to{opacity:0}}
#   </style>
#   <style ng-transition="myhome.ie">
#    .StickyBanner{padding:10px 0;position:relative}.StickyBanner__Close{cursor:pointer;color:#fff;display:flex;align-items:center}.StickyBanner__Close app-mh-icon{font-size:.8em}.StickyBanner__Close:hover{color:#e6e6e6}app-mobile-header{background:#009cdb}
#   </style>
#   <style ng-transition="myhome.ie">
#    .Footer--blue{background:#009cdb;color:#fff}.Footer--grey{color:#555;background-color:#f8f8f8;border-top:2px solid #ddd;border-bottom:2px solid #ddd;padding-bottom:20px}.Footer__LinkContainer{display:flex}@media (max-width:750px){.Footer__LinkContainer{flex-wrap:wrap}}.Footer__LinksPanel{width:25%;font-size:.9em}@media (max-width:750px){.Footer__LinksPanel{width:50%}}.Footer__LinksHeader{display:block;font-weight:700;margin-bottom:5px;font-size:1.2em}.Footer__Container{padding:10px;align-items:center;font-size:.9em;flex-wrap:wrap;margin:0 auto}.Footer__Container--blue{background:#009cdb;color:#fff}.Footer__SiteLinks{margin-bottom:0;padding:0;list-style:none;display:flex;flex-wrap:wrap}.Footer__SiteLinks--column{flex-direction:column}.Footer__SiteLinks li{padding:10px}.Footer__Icon,.Footer__SocialLinks{display:flex;align-items:center}.Footer__Icon{cursor:pointer;padding:5px;border-radius:5px}.Footer__Icon:hover{opacity:.8}.Footer__Icon app-mh-icon{font-size:.8em}.Footer__Icon--facebook{background:#3c5a99;color:#fff;font-size:3em}.Footer__Icon--twitter{color:#fff;background:#2aaae0;font-size:3em}.Footer__Link{display:block;color:#555;cursor:pointer;padding:2px 0}.Footer__Link:hover{text-decoration:underline!important;color:#555}.Footer__Link--white{color:#fff}
#   </style>
#   <style ng-transition="myhome.ie">
#    .MobileHeader{background:#f5f5f5}.MobileHeader app-mh-icon{display:inline-block}.MobileHeader fa-icon{color:#fff}.MobileHeader__Container{height:50px;background:#009cdb;align-items:center}.MobileHeader__Account{background-image:linear-gradient(90deg,#009cdb,#006d99);height:180px;width:100%;position:relative;-webkit-clip-path:polygon(0 0,1600px 0,1600px 55%,0 100%);clip-path:polygon(0 0,1600px 0,1600px 55%,0 100%)}@media (max-width:750px){.MobileHeader__Account{-webkit-clip-path:polygon(0 0,1600px 0,1600px 40%,0 100%);clip-path:polygon(0 0,1600px 0,1600px 40%,0 100%)}}.MobileHeader__BannerHearts{background-image:url(/assets/images/account-banner-tablet.png);width:100%;height:100%;position:absolute;background-size:cover;background-position:50%;z-index:-1}@media (max-width:480px){.MobileHeader__BannerHearts{background-image:url(/assets/images/account-banner-mobile.png)}}.MobileHeader__LogoContainer{max-width:100%}.MobileHeader__Logo{width:100%;max-width:130px;cursor:pointer;height:auto}.MobileHeader__ToolbarsContainer{line-height:0}.MobileHeader__ToolbarsIcon{color:#fff;font-size:1.1em}.MobileHeader--sticky{position:fixed;top:0;z-index:10}.MobileHeader--emptyPlaceholder{padding-bottom:50px}.MobileHeader--emptyAccountPlaceholder{padding-bottom:180px}.MobileHeader__AccountHeading{color:#fff;position:absolute;top:50%;left:50%;transform:translate(-50%,-50%);width:100%;text-align:center}.MobileHeader__AccountHeading h1{font-size:2.1em}@media (max-width:374px){.MobileHeader__AccountHeading h1{font-size:1.8em}}.MobileHeader__BackButton{position:absolute;bottom:5px;left:16px}.notificationIcon{position:relative}.MobileHeaderNotificationNumber{position:absolute;right:5px;top:-5px;background-color:red;border-radius:50%;text-align:center;color:#fff;width:15px;line-height:15px;font-weight:600;font-size:.5em}
#   </style>
#   <style ng-transition="myhome.ie">
#    .MhFormElements__Button{width:100%;height:100%;cursor:pointer;white-space:nowrap;-webkit-user-select:none;user-select:none;border:1px solid transparent;padding:.375rem 1rem;display:flex;align-items:center;justify-content:center;color:#555;background:#fff}.MhFormElements__Button:hover{box-shadow:0 0 0 .2rem rgba(0,156,219,.5)}.PriceRegisterListItem{min-height:90px;padding:5px;display:flex}.PriceRegisterListItem--bordered{border-left:2px solid #eee;border-right:2px solid #eee;border-bottom:2px solid #eee}@media (max-width:992px){.PriceRegisterListItem{font-size:.9em}}@media (max-width:750px){.PriceRegisterListItem{flex-direction:column;height:auto;padding:10px 5px;align-items:center}}.PriceRegisterListItem__Top{align-items:flex-start}@media (max-width:750px){.PriceRegisterListItem__Top{flex-direction:column}}.PriceRegisterListItem__Date{color:#555;width:120px;text-align:right}@media (max-width:750px){.PriceRegisterListItem__Date{text-align:left;font-size:.9em;font-weight:600}}::-webkit-scrollbar{-webkit-appearance:none}::-webkit-scrollbar:vertical{width:11px}::-webkit-scrollbar:horizontal{height:11px}::-webkit-scrollbar-thumb{border-radius:8px;border:2px solid #fff;background-color:rgba(0,0,0,.5)}::-webkit-scrollbar-track{border-radius:8px;background-color:""}.DesktopHeader{align-items:center;height:80px}.DesktopHeader app-mh-icon{display:inline-block}.DesktopHeader app-mh-icon[icon=chevron-down]{font-size:.8em}.DesktopHeader fa-icon{display:inline-block;font-size:1.2em}.DesktopHeader__LogoContainer{min-width:10%;max-width:20%}.DesktopHeader__Logo{width:100%;max-width:175px;cursor:pointer;height:auto}.DesktopHeader__Nav{display:flex;height:100%}.DesktopHeader__NavIcon{color:#009cdb}.DesktopHeader__NavItem{color:#555;cursor:pointer;position:relative}.DesktopHeader__NavItem:hover{background-color:#eee}.DesktopHeader__NavItem--active{border-bottom-width:5px;border-bottom-style:solid}.DesktopHeader__NavItem--accountLink{border:none;color:#009cdb;white-space:nowrap;padding:28px}@media (max-width:1110px){.DesktopHeader__NavItem--accountLink{padding:28px 21px}}.DesktopHeader__ModalLinkText{font-size:.8em;text-align:center;color:#000}.DesktopHeader__NavItemChild{color:#555;padding:28px;white-space:nowrap}@media (max-width:1110px){.DesktopHeader__NavItemChild{padding:28px 21px}}.DesktopHeader__Dropdown{margin:0;padding:0;width:310px;box-shadow:0 10px 32px -8px rgba(0,0,0,.75)}.DesktopHeader__DropdownItem{cursor:pointer;padding:10px 15px;border-bottom:1px solid #eee;font-size:.9em;color:#555;display:flex;justify-content:space-between;align-items:center}.DesktopHeader__DropdownItem:hover{background-color:#eee}.DesktopHeader__NotificationItem{padding:0}.DesktopHeader a:hover{text-decoration:none}.DesktopHeader__DropdownBanner{font-weight:700;font-size:.8em;padding:2px 12px;color:#fff;box-shadow:0 3px 10px -5px #000;text-align:center;background:#009cdb;height:100%}.DesktopHeader__Title{padding-top:10px;text-align:center;font-weight:550}.DesktopHeader__AccountLinks{cursor:pointer;display:flex;align-items:center;height:100%;justify-content:flex-end}.DesktopHeader .dropdown-toggle:after{display:none}.DesktopHeader .HeaderNotificationNumber{position:absolute;right:30px;top:25px;background-color:red;border-radius:50%;text-align:center;color:#fff;width:15px;line-height:15px;font-weight:600;font-size:.5em}.DesktopHeader__NoNotifications{display:flex;align-items:center;justify-content:center;font-size:1em;padding-top:10px;padding-bottom:10px;color:#4e9ddb;font-weight:600;width:100%;margin-bottom:5%;margin-top:5%}.DesktopHeader__ModalSubText{font-size:.9em;color:#a3a3a3}.DesktopHeader__ModalQuestionText{font-size:.9em;color:#000;font-weight:550}.DesktopHeader__ConfirmationButton{width:130px}.DesktopHeader__SubmitButton{width:200px;margin:auto;display:block}.DesktopHeader__CancelReasonTitle{font-weight:550;font-size:1.2em;color:#000}.DesktopHeader__RentalDetails{text-align:center;font-size:.9em}.DesktopHeader__Notifications{height:450px;overflow-y: ...
#   </style>
#   <style ng-transition="myhome.ie">
#    .MhIcon{display:flex}.MhIcon svg{display:inline-block;width:1em;height:1em;stroke-width:0;stroke:currentColor;fill:currentColor}.MhIcon--spin{animation:spin 2s linear infinite}.MhIcon path{fill:inherit;stroke:inherit;stroke-width:inherit;transform:inherit}@keyframes spin{0%{transform:rotate(0deg)}to{transform:rotate(359deg)}}
#   </style>
#   <style ng-transition="myhome.ie">
#    .cdk-high-contrast-active .mat-toolbar{outline:solid 1px}.mat-toolbar-row,.mat-toolbar-single-row{display:flex;box-sizing:border-box;padding:0 16px;width:100%;flex-direction:row;align-items:center;white-space:nowrap}.mat-toolbar-multiple-rows{display:flex;box-sizing:border-box;flex-direction:column;width:100%}
#   </style>
#   <style ng-transition="myhome.ie">
#    .MhButton app-mh-icon{font-size:.8em}.MhButton--disabled{cursor:not-allowed;opacity:.5;pointer-events:none}.MhButton--roundedCorners{border-radius:.25em}.MhButton--fullHeight{height:100%}.MhButton--small{padding:5px}.MhButton--noText{padding:15px!important;font-size:1.2em}.MhButton--boxShadow{box-shadow:1px 1px 4px #adabab!important}.MhButton--iconTop{display:flex;flex-direction:column}.MhButton--circularCorners{border-radius:20px}.MhButton--blue{color:#fff!important;background:#009cdb!important}.MhButton--blue:hover:not([disabled]){background:#008ac2;box-shadow:none}.MhButton--white{border:1px solid #ccc!important;color:#009cdb!important;background:#fff!important}.MhButton--white:hover:not([disabled]){background:#e1e1e1;box-shadow:none}.MhButton--red{color:#fff!important;background-color:#ef5350!important}.MhButton--red:hover:not([disabled]){background:#ed3c39;box-shadow:none}.MhButton--green{color:#fff!important;background-color:#68a42a!important}.MhButton--green:hover:not([disabled]){background:#4e7b20;box-shadow:none}.MhButton--grey{background-color:#ddd!important}.MhButton--grey:hover:not([disabled]){background:#c4c4c4;box-shadow:none}.MhButton--black{background-color:#555!important;color:#fff!important}.MhButton--black:hover:not([disabled]){background:#3c3c3c;box-shadow:none}.MhButton--turquoise{background-color:#17a2b8!important;color:#fff!important}.MhButton--turquoise:hover:not([disabled]){background:#117a8b;box-shadow:none}.MhButton--lightGrey{background-color:#f5f5f5!important;border:1px solid #ccc!important}.MhButton--lightGrey:hover:not([disabled]){background:#dcdcdc;box-shadow:none}
#   </style>
#   <style ng-transition="myhome.ie">
#    .MhFormElements__Button{width:100%;height:100%;cursor:pointer;white-space:nowrap;-webkit-user-select:none;user-select:none;border:1px solid transparent;padding:.375rem 1rem;display:flex;align-items:center;justify-content:center;color:#555;background:#fff}.MhFormElements__Button:hover{box-shadow:0 0 0 .2rem rgba(0,156,219,.5)}.PriceRegisterListItem{min-height:90px;padding:5px;display:flex}.PriceRegisterListItem--bordered{border-left:2px solid #eee;border-right:2px solid #eee;border-bottom:2px solid #eee}@media (max-width:992px){.PriceRegisterListItem{font-size:.9em}}@media (max-width:750px){.PriceRegisterListItem{flex-direction:column;height:auto;padding:10px 5px;align-items:center}}.PriceRegisterListItem__Top{align-items:flex-start}@media (max-width:750px){.PriceRegisterListItem__Top{flex-direction:column}}.PriceRegisterListItem__Date{color:#555;width:120px;text-align:right}@media (max-width:750px){.PriceRegisterListItem__Date{text-align:left;font-size:.9em;font-weight:600}}.SearchResults{background:#fafafa;padding-bottom:10px}.SearchResults--opacity{opacity:.2}.SearchResults__SearchForm{background:#555}.SearchResults__MobileSearchForm{background:#fff}.SearchResults__MobileSearchForm--sticky{position:fixed;top:50px;width:100%;z-index:10;border-bottom:2px solid #009cdb}.SearchResults__LoadingCard{height:250px;width:100%}@media (max-width:750px){.SearchResults__LoadingCard{height:580px}}.SearchResults__Ad{overflow:hidden}.SearchResults__Ad--sticky{position:fixed;z-index:10;top:45px;width:100%}.SearchResults__Ad--fadeOut{opacity:0;transition:opacity 1s linear}.SearchResults__StickyAd{overflow:hidden;position:fixed;z-index:10;overflow-y:auto;padding:15px;transition:top .25s ease-out;margin:0 35px;top:35px}.SearchResults__AdLoader{width:970px;height:90px;background:linear-gradient(90deg,#fff,#eee);background-size:400% 400%;animation:LoadingShimmer 1s ease infinite}@keyframes LoadingShimmer{0%{background-position:0 51%}50%{background-position:100% 50%}to{background-position:0 51%}}.SearchResults__SearchHeader{align-items:center}@media (max-width:992px){.SearchResults__SearchHeader{flex-direction:column-reverse;padding:0}}.SearchResults__SearchControls{display:flex;height:38px}@media (max-width:992px){.SearchResults__SearchControls{margin-top:20px}}@media (max-width:750px){.SearchResults__SearchControls{padding:0!important;font-size:.9em;margin-top:0;margin-bottom:20px;width:100%}.SearchResults__SearchControls div{margin:0!important;flex-grow:1;flex-basis:50%}}.SearchResults__Heading{color:#555;font-size:1.2em;margin-bottom:0}@media (max-width:992px){.SearchResults__Heading{padding:20px}}.SearchResults__Properties{margin:20px auto;width:100%}@media (max-width:750px){.SearchResults__Properties{padding:0;margin:0}}.SearchResults__Properties--watchlist{width:calc(100% - 260px)}.SearchResults__Properties--ad{width:calc(100% - 170px)}.SearchResults__ResultsList{display:flex}.SearchResults__Watchlist{width:250px;margin:20px auto;background:#fff;border:2px solid #eee}.SearchResults__SideAds{width:160px;margin:20px auto}.SearchResults__SideAds--sticky{position:fixed;top:0}.mobile-breadcrumbs{background:#e7ebef}
#   </style>
#   <link href="https://www.myhome.ie/residential/mayo/property-for-sale" rel="canonical"/>
#   <meta content="Listings 1-20 (out of 497) for Mayo property for sale. Find Mayo residential property for sale including houses for sale in Mayo, apartments for sale in Mayo, new homes and sites with MyHome Property listings" name="description"/>
#   <style ng-transition="myhome.ie">
#    @charset "UTF-8";.MhBreadcrumbs{font-size:.8em;color:#fff;display:inline-flex;align-items:center}.MhBreadcrumbs app-mh-icon{font-size:.7em}.MhBreadcrumbs--dark{color:#555}.MhBreadcrumbs__Block{overflow:hidden;margin:0;text-overflow:ellipsis}.MhBreadcrumbs__Link{color:#fff}.MhBreadcrumbs__Link--dark{color:#555}.MhBreadcrumbs__Loading{color:#fff;font-size:.9em}.MhBreadcrumbs__Loading:after{overflow:hidden;display:inline-block;vertical-align:bottom;animation:ellipsis .9s steps(4) infinite;content:"…";width:0}@keyframes ellipsis{to{width:1.25em}}
#   </style>
#   <style ng-transition="myhome.ie">
#    .SearchFormContainer__Count{color:#555}.SearchFormContainer__SearchForm{background:#555}
#   </style>
#   <style ng-transition="myhome.ie">
#    .MhFormElements__Button{width:100%;height:100%;cursor:pointer;white-space:nowrap;-webkit-user-select:none;user-select:none;border:1px solid transparent;padding:.375rem 1rem;display:flex;align-items:center;justify-content:center;color:#555;background:#fff}.MhFormElements__Button:hover{box-shadow:0 0 0 .2rem rgba(0,156,219,.5)}.PriceRegisterListItem{min-height:90px;padding:5px;display:flex}.PriceRegisterListItem--bordered{border-left:2px solid #eee;border-right:2px solid #eee;border-bottom:2px solid #eee}@media (max-width:992px){.PriceRegisterListItem{font-size:.9em}}@media (max-width:750px){.PriceRegisterListItem{flex-direction:column;height:auto;padding:10px 5px;align-items:center}}.PriceRegisterListItem__Top{align-items:flex-start}@media (max-width:750px){.PriceRegisterListItem__Top{flex-direction:column}}.PriceRegisterListItem__Date{color:#555;width:120px;text-align:right}@media (max-width:750px){.PriceRegisterListItem__Date{text-align:left;font-size:.9em;font-weight:600}}::-webkit-scrollbar{-webkit-appearance:none}::-webkit-scrollbar:vertical{width:11px}::-webkit-scrollbar:horizontal{height:11px}::-webkit-scrollbar-thumb{border-radius:8px;border:2px solid #fff;background-color:rgba(0,0,0,.5)}::-webkit-scrollbar-track{border-radius:8px;background-color:""}.AgentsInArea{color:#555;background:#fff;padding:10px}.AgentsInArea__Heading{text-align:center;font-weight:300}.AgentsInArea__AgentsContainer{flex-basis:60%}.AgentsInArea__Agents{max-height:420px;overflow-y:scroll}.AgentsInArea__Agent{display:flex;align-items:center;background:#fff;border:1px solid #eee}.AgentsInArea__Agent--disabled{cursor:not-allowed;opacity:.5;pointer-events:none}.AgentsInArea__Agent--selected{background:#f2f2f2}.AgentsInArea__Agent:hover{cursor:pointer;background:#f2f2f2}.AgentsInArea__AgentDetails{flex-grow:1}.AgentsInArea__AgentLogo{padding:10px;width:100px;overflow:hidden}.AgentsInArea__Name{font-size:1.1em;color:#009cdb}.AgentsInArea__NumberOfProperties,.AgentsInArea__Phone{font-size:.9em}.AgentsInArea__Footer{display:flex}.AgentsInArea__ContactForm{flex-basis:38%}.AgentsInArea__Field::placeholder{font-size:.9em;color:#009cdb}.AgentsInArea__Field.ng-invalid.ng-touched{border:1px solid #ef5350}.AgentsInArea__Field.ng-invalid.ng-touched:focus{box-shadow:0 0 0 .2rem rgba(239,83,80,.25)}.AgentsInArea__TextArea{min-height:210px}.AgentsInArea__Message{font-size:.83em}.AgentsInArea__Message--warning{color:#ef5350}.AgentsInArea__RadioButtons{display:flex;align-content:center;font-size:.9em}
#   </style>
#   <style ng-transition="myhome.ie">
#    .MhSearchForm{position:relative;color:#fff;padding-top:45px;background-color:#555}.MhSearchForm__Row{display:flex;justify-content:space-between}.MhSearchForm__Row--reverse{flex-direction:row-reverse}.MhSearchForm__Input{border:none;padding:9px 15px;display:inline-block;flex-basis:22%;font-size:.9em}.MhSearchForm__Input--disabled{opacity:.65;cursor:not-allowed}.MhSearchForm__Input ::placeholder{color:#555;opacity:1}.MhSearchForm__Label{display:none}.MhSearchForm__InlineSearchButton{width:120px;height:100%;display:flex;flex-direction:column-reverse}.MhSearchForm__InlineSearchButton--hidden{visibility:hidden}.MhSearchForm__Column{flex-grow:1;flex-basis:20%}.MhSearchForm__Checkboxes,.MhSearchForm__MoreFilters{display:flex;align-items:center}.MhSearchForm__Checkboxes{flex-basis:22%;font-size:.9em}.MhSearchForm__AuctionsFooter{display:flex;justify-content:flex-end;align-items:center;margin-top:45px}.MhSearchForm__AuctionsFooterButtons{display:flex;flex-wrap:wrap}.MhSearchForm__Footer{margin-top:12px}
#   </style>
#   <style ng-transition="myhome.ie">
#    .MhFormElements__Button{width:100%;height:100%;cursor:pointer;white-space:nowrap;-webkit-user-select:none;user-select:none;border:1px solid transparent;padding:.375rem 1rem;display:flex;align-items:center;justify-content:center;color:#555;background:#fff}.MhFormElements__Button:hover{box-shadow:0 0 0 .2rem rgba(0,156,219,.5)}.PriceRegisterListItem{min-height:90px;padding:5px;display:flex}.PriceRegisterListItem--bordered{border-left:2px solid #eee;border-right:2px solid #eee;border-bottom:2px solid #eee}@media (max-width:992px){.PriceRegisterListItem{font-size:.9em}}@media (max-width:750px){.PriceRegisterListItem{flex-direction:column;height:auto;padding:10px 5px;align-items:center}}.PriceRegisterListItem__Top{align-items:flex-start}@media (max-width:750px){.PriceRegisterListItem__Top{flex-direction:column}}.PriceRegisterListItem__Date{color:#555;width:120px;text-align:right}@media (max-width:750px){.PriceRegisterListItem__Date{text-align:left;font-size:.9em;font-weight:600}}.MhDropdown{cursor:pointer}.MhDropdown__SelectedItem{overflow:hidden;display:flex;align-items:center}.MhDropdown__Button{justify-content:space-between!important;height:38px!important;font-size:.9em}.MhDropdown__Button[disabled]{cursor:not-allowed;opacity:.5}@media (max-width:992px){.MhDropdown__Button{background:url(/assets/images/chevron-down-solid.svg)!important;background-size:auto .5em!important;background-position:right 16px center!important;background-repeat:no-repeat!important;background-color:#fff!important;-webkit-appearance:none!important;border-radius:.25em!important}}.MhDropdown__Button--notRounded{border-radius:0}.MhDropdown__Button--rounded{border-radius:.25em}.MhDropdown__Button--centered{justify-content:center}.MhDropdown__Button--white{color:#555!important;background-color:#fff!important;border:1px solid #ced4da!important}.MhDropdown__Button--blue{color:#fff!important;background-color:#009cdb!important}.MhDropdown__Button--blue:hover:not([disabled]){background:#008ac2}.MhDropdown__Button--green{color:#fff!important;background-color:#68a42a!important}.MhDropdown__Button--green:hover:not([disabled]){background:#5b9025}.MhDropdown__Button--bordered{border:1px solid #ced4da;border-radius:0;color:#009cdb}.MhDropdown__Label{font-size:1em}@media (max-width:992px){.MhDropdown__Label{font-size:.9em}}.MhDropdown__Chevron{margin-left:5px;font-size:.8em}.MhDropdown__Filter{position:absolute;width:100%}.MhDropdown__Dropdown{font-size:.9em;box-shadow:0 10px 32px -8px rgba(0,0,0,.75)}.MhDropdown__DropdownItems{max-height:300px;overflow-y:auto}.MhDropdown__DropdownItems--filter{margin-top:40px}.MhDropdown__Item{padding:5px 10px;margin:2px;cursor:pointer}.MhDropdown__Item:hover{background-color:#eee}.MhDropdown__Item:active{background-color:#009cdb;color:#fff}.MhDropdown__Item--disabled{cursor:not-allowed;pointer-events:none}.MhDropdown .dropdown-toggle:after{display:none}.MhDropdown ::-webkit-scrollbar{-webkit-appearance:none}.MhDropdown ::-webkit-scrollbar:vertical{width:11px}.MhDropdown ::-webkit-scrollbar:horizontal{height:11px}.MhDropdown ::-webkit-scrollbar-thumb{border-radius:8px;border:2px solid #fff;background-color:rgba(0,0,0,.5)}.MhDropdown ::-webkit-scrollbar-track{border-radius:8px;background-color:""}.MhDropdown.show .MhDropdown__Button{box-shadow:0 0 0 .2rem rgba(0,156,219,.5);background:#009cdb;color:#fff}.MhDropdown.show .MhDropdown__Button--green{background:#68a42a}
#   </style>
#   <style ng-transition="myhome.ie">
#    .MhFormElements__Button{width:100%;height:100%;cursor:pointer;white-space:nowrap;-webkit-user-select:none;user-select:none;border:1px solid transparent;padding:.375rem 1rem;display:flex;align-items:center;justify-content:center;color:#555;background:#fff}.MhFormElements__Button:hover{box-shadow:0 0 0 .2rem rgba(0,156,219,.5)}.PriceRegisterListItem{min-height:90px;padding:5px;display:flex}.PriceRegisterListItem--bordered{border-left:2px solid #eee;border-right:2px solid #eee;border-bottom:2px solid #eee}@media (max-width:992px){.PriceRegisterListItem{font-size:.9em}}@media (max-width:750px){.PriceRegisterListItem{flex-direction:column;height:auto;padding:10px 5px;align-items:center}}.PriceRegisterListItem__Top{align-items:flex-start}@media (max-width:750px){.PriceRegisterListItem__Top{flex-direction:column}}.PriceRegisterListItem__Date{color:#555;width:120px;text-align:right}@media (max-width:750px){.PriceRegisterListItem__Date{text-align:left;font-size:.9em;font-weight:600}}.LocalitySelect{height:100%}.LocalitySelect__Button{background:#fff;border-radius:.25em;justify-content:space-between!important;height:38px!important;border:1px solid #ced4da!important}.LocalitySelect__Button[disabled]{cursor:not-allowed;opacity:.5}.LocalitySelect__Button:hover{box-shadow:0 0 0 .2rem rgba(0,156,219,.5)}.LocalitySelect__Button--active,.LocalitySelect__Button:active{background-color:#009cdb!important;color:#fff!important}.LocalitySelect__Label{font-size:.9em}.LocalitySelect__ButtonRight{overflow:hidden;display:flex;align-items:center}.LocalitySelect__MobileButtonRight{display:flex;align-items:center;justify-content:space-between;width:100%}.LocalitySelect__SelectedItem{float:right;font-size:1em}.LocalitySelect__MobileSelectedItem{font-size:.9em;position:relative;overflow:hidden;text-overflow:ellipsis;display:block}.LocalitySelect__Chevron{margin-left:5px;font-size:.9em}.LocalitySelect__Dropdown{font-size:.9em;box-shadow:0 10px 32px -8px rgba(0,0,0,.75);position:absolute;left:0;background:#fff;z-index:10;padding:10px;margin-top:5px}.LocalitySelect__Controls{display:flex;position:absolute;width:98%}.LocalitySelect__OptionsRow{display:flex;align-items:flex-start;max-height:300px;overflow-y:auto;margin-top:50px}.LocalitySelect__Options{width:100%}.LocalitySelect__Options--quarterWidth{flex-basis:25%}.LocalitySelect__Options--halfWidth{flex-basis:50%}.LocalitySelect__Options--threeQuarterWidth{flex-basis:75%}.LocalitySelect__OptionsColumn{display:flex;flex-wrap:wrap}.LocalitySelect__OptionsColumn:not(:last-child){border-right:1px solid #eee}.LocalitySelect__OptionsHeader{color:#555;padding:5px;border-bottom:1px solid #eee;margin-bottom:10px}.LocalitySelect__Item{display:flex;align-items:flex-start;cursor:pointer;padding:5px;width:25%}.LocalitySelect__Item:hover{background-color:#eee}.LocalitySelect__Item--fullWidth{width:100%}.LocalitySelect__Item--thirdWidth{width:33%}.LocalitySelect__Item--halfWidth{width:50%}.LocalitySelect__Count{margin-left:5px;color:#009cdb}.LocalitySelect__MobileDropdown{width:100%}.LocalitySelect__ModalFooter{display:flex;width:100%;height:60px}.LocalitySelect__ModalFooter app-mh-button{flex-grow:1}.LocalitySelect .dropdown-toggle:after{display:none}.LocalitySelect ::-webkit-scrollbar{-webkit-appearance:none}.LocalitySelect ::-webkit-scrollbar:vertical{width:11px}.LocalitySelect ::-webkit-scrollbar:horizontal{height:11px}.LocalitySelect ::-webkit-scrollbar-thumb{border-radius:8px;border:2px solid #fff;background-color:rgba(0,0,0,.5)}.LocalitySelect ::-webkit-scrollbar-track{border-radius:8px;background-color:""}.MhMultiSelectDropdown.show .MhMultiSelectDropdown__Button{box-shadow:0 0 0 .2rem rgba(0,156,219,.5);background:#009cdb;color:#fff}
#   </style>
#   <style ng-transition="myhome.ie">
#    .MhFormElements__Button{width:100%;height:100%;cursor:pointer;white-space:nowrap;-webkit-user-select:none;user-select:none;border:1px solid transparent;padding:.375rem 1rem;display:flex;align-items:center;justify-content:center;color:#555;background:#fff}.MhFormElements__Button:hover{box-shadow:0 0 0 .2rem rgba(0,156,219,.5)}.PriceRegisterListItem{min-height:90px;padding:5px;display:flex}.PriceRegisterListItem--bordered{border-left:2px solid #eee;border-right:2px solid #eee;border-bottom:2px solid #eee}@media (max-width:992px){.PriceRegisterListItem{font-size:.9em}}@media (max-width:750px){.PriceRegisterListItem{flex-direction:column;height:auto;padding:10px 5px;align-items:center}}.PriceRegisterListItem__Top{align-items:flex-start}@media (max-width:750px){.PriceRegisterListItem__Top{flex-direction:column}}.PriceRegisterListItem__Date{color:#555;width:120px;text-align:right}@media (max-width:750px){.PriceRegisterListItem__Date{text-align:left;font-size:.9em;font-weight:600}}.MhMultiSelectDropdown{height:100%}.MhMultiSelectDropdown__Button{border-radius:.25em;justify-content:space-between!important;height:38px!important;border:1px solid #ced4da!important}.MhMultiSelectDropdown__Button:hover{box-shadow:0 0 0 .2rem rgba(0,156,219,.5)}.MhMultiSelectDropdown__Button:active{background-color:#009cdb!important;color:#fff!important}.MhMultiSelectDropdown__Label{font-size:.9em}.MhMultiSelectDropdown__ButtonRight{display:flex;align-items:center;overflow:hidden}.MhMultiSelectDropdown__MobileButtonRight{display:flex;align-items:center;justify-content:space-between;width:100%}.MhMultiSelectDropdown__SelectedItem{float:right;font-size:.9em}.MhMultiSelectDropdown__MobileSelectedItem{font-size:.9em;position:relative;overflow:hidden;text-overflow:ellipsis;display:block}.MhMultiSelectDropdown__Chevron{margin-left:5px;font-size:.8em}.MhMultiSelectDropdown__Dropdown{font-size:.9em;box-shadow:0 10px 32px -8px rgba(0,0,0,.75)}.MhMultiSelectDropdown__Filter{width:100%;background:#fff;z-index:10}@media (min-width:992px){.MhMultiSelectDropdown__Filter{position:absolute}}@media (max-width:992px){.MhMultiSelectDropdown__Filter{width:100%;padding:15px;background:#fafafa}}.MhMultiSelectDropdown__modal{z-index:1000;position:absolute}.MhMultiSelectDropdown__Controls{display:flex}.MhMultiSelectDropdown__Controls app-mh-button{flex-grow:1}.MhMultiSelectDropdown__ClearSelection{padding:10px;cursor:pointer}.MhMultiSelectDropdown__ClearSelection:active{background-color:#009cdb}.MhMultiSelectDropdown__Options{padding:0 10px;max-height:300px;overflow-y:auto;margin-top:110px}@media (max-width:992px){.MhMultiSelectDropdown__Options{margin-top:0;max-height:none}}.MhMultiSelectDropdown__Item{align-items:center;cursor:pointer;padding:5px;width:100%}.MhMultiSelectDropdown__Item:hover{background-color:#eee}.MhMultiSelectDropdown__Item--halfWidth{width:50%;float:left}.MhMultiSelectDropdown__Count{color:#009cdb;margin:0 5px}.MhMultiSelectDropdown__ModalFooter{display:flex;height:60px}.MhMultiSelectDropdown__ModalFooter app-mh-button{flex-grow:1}.MhMultiSelectDropdown select{color:#555;background:#fff;border-radius:.25em;display:flex;justify-content:space-between;padding:.375rem .75rem}.MhMultiSelectDropdown .dropdown-toggle:after{display:none}.MhMultiSelectDropdown__MobileDropdown{width:100%}.MhMultiSelectDropdown ::-webkit-scrollbar{-webkit-appearance:none}.MhMultiSelectDropdown ::-webkit-scrollbar:vertical{width:11px}.MhMultiSelectDropdown ::-webkit-scrollbar:horizontal{height:11px}.MhMultiSelectDropdown ::-webkit-scrollbar-thumb{border-radius:8px;border:2px solid #fff;background-color:rgba(0,0,0,.5)}.MhMultiSelectDropdown ::-webkit-scrollbar-track{border-radius:8px;background-color:""}.MhMultiSelectDropdown.show .MhMultiSelectDropdown__Button{box-shadow:0 0 0 .2rem rgba(0,156,219,.5);background:#009cdb;color:#fff}
#   </style>
#   <style ng-transition="myhome.ie">
#    .SearchFormFooter{display:flex;justify-content:flex-end;align-items:center}.SearchFormFooter span{cursor:pointer}.SearchFormFooter span:hover{color:#e6e6e6;text-decoration:underline}.SearchFormFooter--spaced{justify-content:space-between}.SearchFormFooter--reversed{flex-direction:row-reverse}.SearchFormFooter__AdvancedFilterButton{display:flex;align-items:center}.SearchFormFooter__AdvancedFilterButton app-mh-icon{font-size:.8em}.SearchFormFooter__FooterButtons{display:flex;flex-wrap:wrap;align-items:center}.SearchFormFooter__AdvancedFilters{align-items:center}
#   </style>
#   <style ng-transition="myhome.ie">
#    .MhCheckBox{cursor:pointer;display:inline-flex;align-items:center}.MhCheckBox__Box{min-width:15px;min-height:15px;position:relative}.MhCheckBox__Box--light{border:2px solid #fff}.MhCheckBox__Box--dark{border:1px solid #555}.MhCheckBox__Box--rounded{border-radius:4px}.MhCheckBox__Check{color:#009cdb;position:absolute;font-size:1.1em;top:-2px}.MhCheckBox__Label--light{color:#fff}.MhCheckBox__Label--dark{color:#555}
#   </style>
#   <style ng-transition="myhome.ie">
#    .MhFormElements__Button{width:100%;height:100%;cursor:pointer;white-space:nowrap;-webkit-user-select:none;user-select:none;border:1px solid transparent;padding:.375rem 1rem;display:flex;align-items:center;justify-content:center;color:#555;background:#fff}.MhFormElements__Button:hover{box-shadow:0 0 0 .2rem rgba(0,156,219,.5)}.PriceRegisterListItem{min-height:90px;padding:5px;display:flex}.PriceRegisterListItem--bordered{border-left:2px solid #eee;border-right:2px solid #eee;border-bottom:2px solid #eee}@media (max-width:992px){.PriceRegisterListItem{font-size:.9em}}@media (max-width:750px){.PriceRegisterListItem{flex-direction:column;height:auto;padding:10px 5px;align-items:center}}.PriceRegisterListItem__Top{align-items:flex-start}@media (max-width:750px){.PriceRegisterListItem__Top{flex-direction:column}}.PriceRegisterListItem__Date{color:#555;width:120px;text-align:right}@media (max-width:750px){.PriceRegisterListItem__Date{text-align:left;font-size:.9em;font-weight:600}}.MhDfpAd{position:relative;overflow:hidden}.MhDfpAd__Loader{position:absolute;width:100%;height:100%;background:linear-gradient(90deg,#fff,#eee);background-size:400% 400%;animation:LoadingShimmer 1s ease infinite}@keyframes LoadingShimmer{0%{background-position:0 51%}50%{background-position:100% 50%}to{background-position:0 51%}}.MhDfpAd__Ad{z-index:1}.MhDfpAd__TargetingValues{position:absolute;font-size:0}.MhDfpAd iframe{z-index:2}
#   </style>
#   <style ng-transition="myhome.ie">
#    .SaveSearch{display:flex}.SaveSearch--column{flex-direction:column;justify-content:space-between}.SaveSearch--column app-mh-button,.SaveSearch--column app-mh-dropdown{margin:0 0 10px!important;width:100%}@media (max-width:750px){.SaveSearch{flex-direction:column;font-size:.9em;justify-content:space-between;height:130px;width:100%}.SaveSearch app-mh-button,.SaveSearch app-mh-dropdown{height:38px;margin:0!important;width:100%}}.MobileSaveSearch__Buttton{flex-basis:50%}
#   </style>
#   <style ng-transition="myhome.ie">
#    .PropertyListingCard{border:2px solid #eee;background-color:#fff;min-height:250px;position:relative;display:flex}.PropertyListingCard app-mh-property-info-strip{display:block}.PropertyListingCard--TopSpot{background:#eaf3f8;border:1px solid #60c0e8}.PropertyListingCard__ImageContainer{border-right:2px solid #eee;width:35%;position:relative;overflow:hidden}.PropertyListingCard__Image{cursor:pointer;width:100%;height:auto}.PropertyListingCard__Content{width:55%;border-right:2px solid #eee;padding:10px;position:relative;display:flex;justify-content:space-between;flex-direction:column}.PropertyListingCard__StatusContainer{display:flex;justify-content:flex-end}.PropertyListingCard__Status{padding:5px 10px}.PropertyListingCard__Status span{font-size:.8em;font-weight:700;color:#fff}.PropertyListingCard__Status--red{background:#ef4c4c}.PropertyListingCard__Status--green{background:#097a6c}.PropertyListingCard__Status--orange{background:orange}.PropertyListingCard__Sidebar{width:20%;padding:10px;display:flex;flex-direction:column;justify-content:space-around}.PropertyListingCard__MediaIcons{position:absolute;bottom:0;right:0;display:flex;font-size:.8em}.PropertyListingCard__MediaIcon{background:rgba(0,0,0,.65);color:#fff;padding:10px;display:flex;align-items:center}.PropertyListingCard__Price{color:#333;font-size:1.8em;font-weight:300}.PropertyListingCard__PriceChange{font-size:.65em}.PropertyListingCard__Address{font-size:1.3em;cursor:pointer;color:#009cdb}.PropertyListingCard__GroupLink{cursor:pointer}.PropertyListingCard__GroupLink--disabled{pointer-events:none}.PropertyListingCard__GroupLogo{width:90px;height:90px}.PropertyListingCard__GroupLogo--small{width:60px;height:60px}.PropertyListingCard__ButtonsFooter app-mh-button{flex-basis:45%}.PropertyListingCard__TransactLogo{position:absolute;bottom:0;left:0;background:#fff;padding:5px;width:110px}.PropertyListingCard__Map{position:absolute;height:100%;width:100%;margin:-10px;z-index:100}.PropertyListingCard__PremiumRibbon{font-size:.9em;padding:5px 0;position:absolute;color:#fff;font-weight:600;width:180px;box-shadow:0 3px 10px -5px #000;text-align:center;transform:rotate(-45deg);-webkit-transform:rotate(-45deg);left:-40px;top:30px}.PropertyListingCard__PremiumRibbon--Green{background:#68a42a}.PropertyListingCard__PremiumRibbon--Blue{background:#009cdb}.PropertyListingCard__ViewGalleryButton{position:absolute;color:#fff;font-size:.8em;bottom:0;left:0;background:rgba(0,0,0,.65);cursor:pointer;padding:10px}.PropertyListingCard__PromotionalText{display:inline-block;overflow:hidden;white-space:nowrap;text-overflow:ellipsis;background:#ef5350;color:#fff;text-transform:uppercase;font-size:.9em;padding:5px}.PropertyListingCard__Easyrent{display:flex;justify-content:flex-end}
#   </style>
#   <style ng-transition="myhome.ie">
#    .PropertyInfoStrip{overflow:hidden;text-overflow:ellipsis;color:#555}.PropertyInfoStrip--bordered{background-color:#f9f9f9;border:1px solid #eee;padding:.5em}.PropertyInfoStrip--mobile{font-size:.9em}.PropertyInfoStrip__Detail{border-right:1px solid #ccc;padding-right:5px;display:inline-flex;align-items:center;margin-right:5px}.PropertyInfoStrip__Detail--light{color:#fff}.PropertyInfoStrip__Detail--dark{color:#555}.PropertyInfoStrip__Detail:first-child{padding-left:0!important}.PropertyInfoStrip__Detail:last-child{border-right:none;padding-right:0}@media (max-width:750px){.PropertyInfoStrip__Detail{border-right:none}}
#   </style>
#   <style ng-transition="myhome.ie">
#    .DesktopPagination .ngx-pagination{padding-inline-start:0;display:flex;align-items:center;justify-content:center}.DesktopPagination .ngx-pagination :hover{border:2px solid #009cdb}.DesktopPagination .ngx-pagination a:focus,.DesktopPagination .ngx-pagination a:hover{background:none;text-decoration:none;border:none;outline:none}.DesktopPagination .ngx-pagination span:hover{border:none}.DesktopPagination .ngx-pagination .disabled{display:none}.DesktopPagination .ngx-pagination .current,.DesktopPagination .ngx-pagination .pagination-next,.DesktopPagination .ngx-pagination .pagination-previous{background:#009cdb;border:2px solid #009cdb}.DesktopPagination .ngx-pagination .current span,.DesktopPagination .ngx-pagination .pagination-next span,.DesktopPagination .ngx-pagination .pagination-previous span{display:block;padding:.1875rem .625rem}.DesktopPagination .ngx-pagination .current a,.DesktopPagination .ngx-pagination .pagination-next a,.DesktopPagination .ngx-pagination .pagination-previous a{color:#fff}.DesktopPagination .ngx-pagination li{padding:4px;border-radius:4px;border:2px solid #ccc;margin-right:1em}.DesktopPagination .ngx-pagination li :focus{border:none}
#   </style>
#   <style ng-transition="myhome.ie">
#    .ngx-pagination {
#   margin-left: 0;
#   margin-bottom: 1rem; }
#   .ngx-pagination::before, .ngx-pagination::after {
#     content: ' ';
#     display: table; }
#   .ngx-pagination::after {
#     clear: both; }
#   .ngx-pagination li {
#     -moz-user-select: none;
#     -webkit-user-select: none;
#     -ms-user-select: none;
#     margin-right: 0.0625rem;
#     border-radius: 0; }
#   .ngx-pagination li {
#     display: inline-block; }
#   .ngx-pagination a,
#   .ngx-pagination button {
#     color: #0a0a0a;
#     display: block;
#     padding: 0.1875rem 0.625rem;
#     border-radius: 0; }
#     .ngx-pagination a:hover,
#     .ngx-pagination button:hover {
#       background: #e6e6e6; }
#   .ngx-pagination .current {
#     padding: 0.1875rem 0.625rem;
#     background: #2199e8;
#     color: #fefefe;
#     cursor: default; }
#   .ngx-pagination .disabled {
#     padding: 0.1875rem 0.625rem;
#     color: #cacaca;
#     cursor: default; }
#     .ngx-pagination .disabled:hover {
#       background: transparent; }
#   .ngx-pagination a, .ngx-pagination button {
#     cursor: pointer; }
#
# .ngx-pagination .pagination-previous a::before,
# .ngx-pagination .pagination-previous.disabled::before {
#   content: '«';
#   display: inline-block;
#   margin-right: 0.5rem; }
#
# .ngx-pagination .pagination-next a::after,
# .ngx-pagination .pagination-next.disabled::after {
#   content: '»';
#   display: inline-block;
#   margin-left: 0.5rem; }
#
# .ngx-pagination .show-for-sr {
#   position: absolute !important;
#   width: 1px;
#   height: 1px;
#   overflow: hidden;
#   clip: rect(0, 0, 0, 0); }
# .ngx-pagination .small-screen {
#   display: none; }
# @media screen and (max-width: 601px) {
#   .ngx-pagination.responsive .small-screen {
#     display: inline-block; }
#   .ngx-pagination.responsive li:not(.small-screen):not(.pagination-previous):not(.pagination-next) {
#     display: none; }
# }
#   </style>
#  </head>
#  <body>
#   <app-root ng-version="11.0.9">
#    <!-- -->
#    <div>
#     <header>
#      <app-header-container>
#       <app-mobile-header class="MhHelper__MobileOnly">
#        <div class="MobileHeader">
#         <mat-toolbar class="mat-toolbar MobileHeader__Container MhHelper__Flex--spaced mat-toolbar-single-row">
#          <a class="MobileHeader__LogoContainer" href="">
#           <img alt="My Home Logo" class="MobileHeader__Logo" height="71" src="../../assets/images/newMobileLogo.png" width="333"/>
#          </a>
#          <div class="MobileHeader__ToolbarsContainer MhHelper__Flex--centered">
#           <!-- -->
#           <!-- -->
#           <!-- -->
#           <div class="ml-3">
#            <app-mh-icon class="MobileHeader__ToolbarsIcon" icon="user">
#             <div aria-hidden="true" class="MhIcon">
#              <svg>
#               <use xlink:href="../../../../assets/images/mh-icons.svg#user">
#               </use>
#              </svg>
#             </div>
#            </app-mh-icon>
#           </div>
#           <!-- -->
#           <div class="ml-3">
#            <app-mh-icon class="MobileHeader__ToolbarsIcon" icon="bars">
#             <div aria-hidden="true" class="MhIcon">
#              <svg>
#               <use xlink:href="../../../../assets/images/mh-icons.svg#bars">
#               </use>
#              </svg>
#             </div>
#            </app-mh-icon>
#           </div>
#          </div>
#         </mat-toolbar>
#        </div>
#        <!-- -->
#        <!-- -->
#       </app-mobile-header>
#       <app-desktop-header class="MhHelper__DesktopOnly">
#        <!-- -->
#        <div class="container">
#         <nav class="DesktopHeader MhHelper__Flex--spaced">
#          <a class="DesktopHeader__LogoContainer" href="/">
#           <img alt="My Home Logo" class="DesktopHeader__Logo" height="35" src="../../assets/images/new_logo_v2.png" width="200"/>
#          </a>
#          <div class="DesktopHeader__Nav">
#           <div class="DesktopHeader__NavItem dropdown DesktopHeader__NavItem--active" ngbdropdown="" style="border-bottom-color:#009cdb;">
#            <div aria-expanded="false" aria-haspopup="true" class="dropdown-toggle DesktopHeader__NavItemChild DesktopHeader__NavItemChild--active" ngbdropdowntoggle="">
#             Buy
#             <app-mh-icon class="ml-1" icon="chevron-down">
#              <div aria-hidden="true" class="MhIcon">
#               <svg>
#                <use xlink:href="../../../../assets/images/mh-icons.svg#chevron-down">
#                </use>
#               </svg>
#              </div>
#             </app-mh-icon>
#            </div>
#            <div class="DesktopHeader__Dropdown dropdown-menu" ngbdropdownmenu="" x-placement="bottom-left">
#             <div>
#              <a class="dropdown-item DesktopHeader__DropdownItem" href="residential/videotours/ireland/property-for-sale" ngbdropdownitem="">
#               Video Tours
#               <span class="DesktopHeader__DropdownBanner">
#                New
#               </span>
#               <!-- -->
#              </a>
#             </div>
#             <div>
#              <a class="dropdown-item DesktopHeader__DropdownItem" href="residential/ireland/house-for-sale" ngbdropdownitem="">
#               Houses For Sale
#               <!-- -->
#              </a>
#             </div>
#             <div>
#              <a class="dropdown-item DesktopHeader__DropdownItem" href="residential/ireland/apartment-for-sale" ngbdropdownitem="">
#               Apartments For Sale
#               <!-- -->
#              </a>
#             </div>
#             <div>
#              <a class="dropdown-item DesktopHeader__DropdownItem" href="residential/ireland/new-homes/property-for-sale" ngbdropdownitem="">
#               New Homes
#               <!-- -->
#              </a>
#             </div>
#             <div>
#              <a class="dropdown-item DesktopHeader__DropdownItem" href="residential/ireland/sale-agreed-property" ngbdropdownitem="">
#               Sale Agreed
#               <!-- -->
#              </a>
#             </div>
#             <div>
#              <a class="dropdown-item DesktopHeader__DropdownItem" href="residential/ireland/sold-property" ngbdropdownitem="">
#               Sold
#               <!-- -->
#              </a>
#             </div>
#             <div>
#              <a class="dropdown-item DesktopHeader__DropdownItem" href="holiday-homes/overseas/property-for-sale" ngbdropdownitem="">
#               Overseas Holiday Homes
#               <!-- -->
#              </a>
#             </div>
#             <div>
#              <a class="dropdown-item DesktopHeader__DropdownItem" href="residential/auctions/ireland/auction-property-for-sale" ngbdropdownitem="">
#               Properties for Auction
#               <!-- -->
#              </a>
#             </div>
#             <div>
# ...
#                  <app-mh-button aria-hidden="true" class="ng-tns-c427-20" color="white" icon="map">
#                   <button class="MhFormElements__Button MhButton-- MhButton--white MhButton--roundedCorners MhButton--noText" id="">
#                    <app-mh-icon class="ng-star-inserted">
#                     <div aria-hidden="true" class="MhIcon">
#                      <svg>
#                       <use xlink:href="../../../../assets/images/mh-icons.svg#map">
#                       </use>
#                      </svg>
#                     </div>
#                    </app-mh-icon>
#                    <!-- -->
#                    <!-- -->
#                    <span>
#                    </span>
#                    <!-- -->
#                   </button>
#                  </app-mh-button>
#                  <app-mh-button aria-hidden="true" class="ng-tns-c427-20 sel_save_icon_not_saved" color="white">
#                   <button class="MhFormElements__Button MhButton-- MhButton--white MhButton--roundedCorners MhButton--noText" id="4533868">
#                    <app-mh-icon class="ng-star-inserted">
#                     <div aria-hidden="true" class="MhIcon">
#                      <svg>
#                       <use xlink:href="../../../../assets/images/mh-icons.svg#heart-open">
#                       </use>
#                      </svg>
#                     </div>
#                    </app-mh-icon>
#                    <!-- -->
#                    <!-- -->
#                    <span>
#                    </span>
#                    <!-- -->
#                   </button>
#                  </app-mh-button>
#                 </div>
#                 <!-- -->
#                 <!-- -->
#                </div>
#                <!-- -->
#               </div>
#               <!-- -->
#               <!-- -->
#               <!-- -->
#               <!-- -->
#               <!-- -->
#               <!-- -->
#              </app-mh-property-listing-card>
#             </div>
#            </div>
#            <!-- -->
#           </div>
#           <!-- -->
#          </div>
#          <!-- -->
#          <div class="ng-star-inserted">
#           <div>
#           </div>
#           <div>
#            <!-- -->
#           </div>
#          </div>
#          <!-- -->
#         </div>
#         <div class="container mb-3 ng-star-inserted">
#          <mh-pagination>
#           <app-desktop-pagination class="ng-star-inserted">
#            <pagination-controls class="DesktopPagination">
#             <pagination-template>
#              <ul aria-label="Pagination" class="ngx-pagination ng-star-inserted" role="navigation">
#               <li class="pagination-previous disabled ng-star-inserted">
#                <!-- -->
#                <span class="ng-star-inserted">
#                 Previous
#                 <span class="show-for-sr">
#                  page
#                 </span>
#                </span>
#                <!-- -->
#               </li>
#               <!-- -->
#               <li class="small-screen">
#                1 / 25
#               </li>
#               <li class="current ng-star-inserted">
#                <!-- -->
#                <span class="show-for-sr ng-star-inserted">
#                 You're on page
#                </span>
#                <span class="ng-star-inserted">
#                 1
#                </span>
#                <!-- -->
#                <!-- -->
#               </li>
#               <li class="ng-star-inserted">
#                <a class="ng-star-inserted" tabindex="0">
#                 <span class="show-for-sr">
#                  page
#                 </span>
#                 <span>
#                  2
#                 </span>
#                </a>
#                <!-- -->
#                <!-- -->
#               </li>
#               <li class="ng-star-inserted">
#                <a class="ng-star-inserted" tabindex="0">
#                 <span class="show-for-sr">
#                  page
#                 </span>
#                 <span>
#                  3
#                 </span>
#                </a>
#                <!-- -->
#                <!-- -->
#               </li>
#               <li class="ng-star-inserted">
#                <a class="ng-star-inserted" tabindex="0">
#                 <span class="show-for-sr">
#                  page
#                 </span>
#                 <span>
#                  4
#                 </span>
#                </a>
#                <!-- -->
#                <!-- -->
#               </li>
#               <li class="ng-star-inserted">
#                <a class="ng-star-inserted" tabindex="0">
#                 <span class="show-for-sr">
#                  page
#                 </span>
#                 <span>
#                  5
#                 </span>
#                </a>
#                <!-- -->
#                <!-- -->
#               </li>
#               <li class="ellipsis ng-star-inserted">
#                <a class="ng-star-inserted" tabindex="0">
#                 <span class="show-for-sr">
#                  page
#                 </span>
#                 <span>
#                  ...
#                 </span>
#                </a>
#                <!-- -->
#                <!-- -->
#               </li>
#               <li class="ng-star-inserted">
#                <a class="ng-star-inserted" tabindex="0">
#                 <span class="show-for-sr">
#                  page
#                 </span>
#                 <span>
#                  25
#                 </span>
#                </a>
#                <!-- -->
#                <!-- -->
#               </li>
#               <!-- -->
#               <li class="pagination-next ng-star-inserted">
#                <a aria-label="Next page" class="ng-star-inserted" tabindex="0">
#                 Next
#                 <span class="show-for-sr">
#                  page
#                 </span>
#                </a>
#                <!-- -->
#                <!-- -->
#               </li>
#               <!-- -->
#              </ul>
#              <!-- -->
#             </pagination-template>
#            </pagination-controls>
#            <div class="ng-star-inserted">
#             <a href="/residential/mayo/property-for-sale?page=2">
#             </a>
#            </div>
#            <div class="ng-star-inserted">
#             <a href="/residential/mayo/property-for-sale?page=3">
#             </a>
#            </div>
#            <div class="ng-star-inserted">
#             <a href="/residential/mayo/property-for-sale?page=4">
#             </a>
#            </div>
#            <div class="ng-star-inserted">
#             <a href="/residential/mayo/property-for-sale?page=5">
#             </a>
#            </div>
#            <div class="ng-star-inserted">
#             <a href="/residential/mayo/property-for-sale?page=25">
#             </a>
#            </div>
#            <!-- -->
#           </app-desktop-pagination>
#           <!-- -->
#           <!-- -->
#          </mh-pagination>
#         </div>
#         <!-- -->
#         <div class="SearchResults__ResultsList container ng-star-inserted">
#          Looking for a new home in Mayo? Find out more in our
#          <a href="/neighbourhood-guide/mayo/2781" target="_blank">
#           Mayo Neighbourhood Guide.
#          </a>
#         </div>
#         <!-- -->
#         <div class="container my-3">
#          <app-agents-in-area-message>
#           <!-- -->
#          </app-agents-in-area-message>
#         </div>
#        </div>
#        <!-- -->
#       </div>
#       <!-- -->
#       <!-- -->
#      </div>
#     </app-residential-search-results>
#     <!-- -->
#     <footer>
#      <app-footer>
#       <div class="Footer">
#        <div class="Footer--grey">
#         <div class="container Footer__LinkContainer MhHelper__Flex--spaced mt-3">
#          <div class="Footer__LinksPanel">
#           <span class="Footer__LinksHeader">
#            Popular Searches
#           </span>
#           <ul class="list-unstyled">
#            <li>
#             <a class="Footer__Link" href="residential/ireland/property-for-sale">
#              Property for Sale
#             </a>
#            </li>
#            <li>
#             <a class="Footer__Link" href="residential/ireland/new-homes/property-for-sale">
#              New Homes for Sale
#             </a>
#            </li>
#            <li>
#             <a class="Footer__Link" href="rentals/ireland/property-to-rent">
#              Property to Rent
#             </a>
#            </li>
#            <!-- -->
#           </ul>
#          </div>
#          <div class="Footer__LinksPanel">
#           <span class="Footer__LinksHeader">
#            Popular Searches by Area
#           </span>
#           <ul class="list-unstyled">
#            <li>
#             <a class="Footer__Link" href="residential/dublin/property-for-sale">
#              Property Dublin
#             </a>
#            </li>
#            <li>
#             <a class="Footer__Link" href="residential/waterford/property-for-sale">
#              Property Waterford
#             </a>
#            </li>
#            <li>
#             <a class="Footer__Link" href="residential/galway/property-for-sale">
#              Property Galway
#             </a>
#            </li>
#            <li>
#             <a class="Footer__Link" href="residential/limerick/property-for-sale">
#              Property Limerick
#             </a>
#            </li>
#            <li>
#             <a class="Footer__Link" href="residential/cork/property-for-sale">
#              Property Cork
#             </a>
#            </li>
#            <!-- -->
#           </ul>
#          </div>
#          <div class="Footer__LinksPanel">
#           <span class="Footer__LinksHeader">
#            Popular Tools
#           </span>
#           <a class="Footer__Link" href="estate-agents">
#            Estate Agents
#           </a>
#           <a class="Footer__Link" href="mortgages">
#            Mortgage Quotes
#           </a>
#           <a class="Footer__Link" href="pricechanges">
#            Latest Price Changes
#           </a>
#           <a class="Footer__Link" href="priceregister">
#            Property Price Register
#           </a>
#           <a class="Footer__Link" href="https://services.myhome.ie/ber-certificate-assessor">
#            BER Assessors
#           </a>
#           <a class="Footer__Link" href="https://services.myhome.ie/property-conveyancing-solicitor">
#            Property Conveyancing Solicitors
#           </a>
#           <a class="Footer__Link" href="https://services.myhome.ie/pre-purchase-structural-survey">
#            Pre Purchase Surveyors
#           </a>
#          </div>
#          <div class="Footer__LinksPanel">
#           <span class="Footer__LinksHeader">
#            Regular
#           </span>
#           <a class="Footer__Link" href="https://blog.myhome.ie">
#            MyHome Blog
#           </a>
#           <a class="Footer__Link" href="neighbourhood-guide">
#            Area Guides
#           </a>
#           <a class="Footer__Link" href="reports">
#            Property Reports
#           </a>
#           <a class="Footer__Link" href="recent">
#            Recently Added
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="Footer__Container MhHelper__Flex--spaced container">
#         <div class="Footer__SocialLinks">
#          <a aria-label="Facebook" class="Footer__Icon Footer__Icon--facebook mr-2" href="https://www.facebook.com/MyHome.ie" rel="noopener" target="_blank">
#           <app-mh-icon icon="facebook">
#            <div aria-hidden="true" class="MhIcon">
#             <svg>
#              <use xlink:href="../../../../assets/images/mh-icons.svg#facebook">
#              </use>
#             </svg>
#            </div>
#           </app-mh-icon>
#          </a>
#          <a aria-label="Twitter" class="Footer__Icon Footer__Icon--twitter mr-2" href="https://twitter.com/myhomeproperty" rel="noopener" target="_blank ">
#           <app-mh-icon icon="twitter">
#            <div aria-hidden="true" class="MhIcon">
#             <svg>
#              <use xlink:href="../../../../assets/images/mh-icons.svg#twitter">
#              </use>
#             </svg>
#            </div>
#           </app-mh-icon>
#          </a>
#          <a class="Footer__Icon Footer__Icon--blog" href="https://blog.myhome.ie" rel="noopener">
#           MyHome Blog
#           <app-mh-icon class="ml-2" icon="caret-right">
#            <div aria-hidden="true" class="MhIcon">
#             <svg>
#              <use xlink:href="../../../../assets/images/mh-icons.svg#caret-right">
#              </use>
#             </svg>
#            </div>
#           </app-mh-icon>
#          </a>
#         </div>
#         <ul class="Footer__SiteLinks MhHelper__Flex">
#          <li>
#           <a class="Footer__Link" href="help">
#            Help
#           </a>
#          </li>
#          <li>
#           <a class="Footer__Link" href="jobs">
#            Jobs
#           </a>
#          </li>
#          <li>
#           <a class="Footer__Link" href="place-ad">
#            Advertise
#           </a>
#          </li>
#          <!-- -->
#          <li>
#           <a class="Footer__Link" href="contact">
#            Contact Us
#           </a>
#          </li>
#          <li>
#           <a class="Footer__Link" href="about">
#            About
#           </a>
#          </li>
#          <li>
#           <button class="Footer__Link ot-sdk-show-settings" id="ot-sdk-btn">
#            Cookie Settings
#           </button>
#          </li>
#         </ul>
#        </div>
#        <div class="Footer--blue">
#         <div class="Footer__Container MhHelper__Flex--spaced container">
#          <span>
#           © Copyright MyHome.ie 2021
#          </span>
#          <ul class="Footer__SiteLinks">
#           <li>
#            <a class="Footer__Link Footer__Link--white" href="advice/property-market-4/buying-5/renting-13/property-advertisement-equality-guidelines/65/4-5-13">
#             Equality Guidelines
#            </a>
#           </li>
#           <li>
#            <a class="Footer__Link Footer__Link--white" href="terms">
#             Terms &amp; Conditions
#            </a>
#           </li>
#           <li>
#            <a class="Footer__Link Footer__Link--white" href="cookiePolicy">
#             Cookie Policy
#            </a>
#           </li>
#           <li>
#            <a class="Footer__Link Footer__Link--white" href="privacy">
#             Privacy Policy
#            </a>
#           </li>
#           <li>
#            <a class="Footer__Link Footer__Link--white" href="sitemap">
#             Sitemap
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </app-footer>
#     </footer>
#    </div>
#    <!-- -->
#    <!-- -->
#   </app-root>
#   <iframe class="optanon-category-C0004" data-src="https://3339216.fls.doubleclick.net/activityi;src=3339216;type=MyWor0;cat=Myhom0;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;ord=1;num=1?" frameborder="0" height="1" style="display:none" width="1">
#   </iframe>
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-53CJ82W" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager -->
#   <!-- Privacy and Cookie policy script -->
#   <script charset="UTF-8" id="otprivacy-notice-script" src="https://privacyportalde-cdn.onetrust.com/privacy-notice-scripts/otnotice-1.0.min.js" type="text/javascript">
#    settings = "eyJjYWxsYmFja1VybCI6Imh0dHBzOi8vcHJpdmFjeXBvcnRhbC1kZS5vbmV0cnVzdC5jb20vcmVxdWVzdC92MS9wcml2YWN5Tm90aWNlcy9zdGF0cy92aWV3cyJ9"
#   </script>
#   <script crossorigin="anonymous" defer="" integrity="sha384-+BzaKBz7Nf3mtjOEV3edPmk+wW87IBl5k8SLivWq/xOWEMXcPeq+tmtjbuUn+ynM" src="runtime.1021bee7d8633d060b68.js">
#   </script>
#   <script crossorigin="anonymous" defer="" integrity="sha384-/O16a+zbmYcIpgWtYxKvOTupXZgYtH641crxTn5H5+0EdV6Kdxk8YBbhrsTAjG4M" src="polyfills.cfd0bed0d120d4caf27f.js">
#   </script>
#   <script crossorigin="anonymous" defer="" integrity="sha384-El8Kk4GUCBsQfn62FF4/Kwb5kV87kp5rOSvfW6QcfroOX2EMtwjvveCep3L3Y3wN" src="scripts.5cea690fab5e508dbdaf.js">
#   </script>
#   <script crossorigin="anonymous" defer="" integrity="sha384-rzmKhu+nrub2gSPcw4B9JSqPPUYpKoq9KTRcmKInnU/9OCtrtsKELrMTTXb2PxRX" src="main.5bf4761df2cecc3a8972.js">
#   </script>
#   <script id="myhome.ie-state" type="application/json">
#    {}
#   </script>
#  </body>
# </html>

# %%
listings = soup.find("div", class_="PropertyListingCard")
print(listings.prettify())
# Out:
# <div class="PropertyListingCard ng-tns-c427-0 PropertyListingCard--TopSpot">
#  <!-- -->
#  <div class="PropertyListingCard__ImageContainer MhHelper__Flex--centered ng-tns-c427-0">
#   <a class="ng-tns-c427-0" href="/residential/brochure/carrowbeg-westport-mayo/4532273">
#    <!-- -->
#    <span class="PropertyListingCard__PremiumRibbon PropertyListingCard__PremiumRibbon--Blue ng-tns-c427-0 ng-star-inserted">
#     FEATURED
#    </span>
#    <!-- -->
#    <!-- -->
#    <!-- -->
#    <!-- -->
#    <img alt="Main Image for Carrowbeg, Westport, Mayo" class="PropertyListingCard__Image ng-tns-c427-0 ng-failed-lazyloaded ng-lazyloaded" defaultimage="../../../../../assets/images/home-banner-pattern.png" height="279" offset="200" src="../../../../../assets/images/home-banner-pattern.png" width="372"/>
#    <div class="PropertyListingCard__MediaIcons ng-tns-c427-0">
#     <!-- -->
#     <div class="PropertyListingCard__MediaIcon ng-tns-c427-0 ng-star-inserted">
#      <app-mh-icon class="mr-1 ng-tns-c427-0" icon="camera">
#       <div aria-hidden="true" class="MhIcon">
#        <svg>
#         <use xlink:href="../../../../assets/images/mh-icons.svg#camera">
#         </use>
#        </svg>
#       </div>
#      </app-mh-icon>
#      6
#     </div>
#     <!-- -->
#    </div>
#   </a>
#   <!-- -->
#  </div>
#  <div class="PropertyListingCard__Content ng-tns-c427-0">
#   <picture class="ng-tns-c427-0">
#    <source class="ng-tns-c427-0" media="(max-width: 1220px)" srcset=""/>
#    <source class="ng-tns-c427-0" media="(max-width: 1020px)" srcset=""/>
#    <!-- -->
#   </picture>
#   <div class="PropertyListingCard__PropertyInfo ng-tns-c427-0">
#    <!-- -->
#    <div class="PropertyListingCard__Price ng-tns-c427-0">
#     €400,000
#    </div>
#    <a class="PropertyListingCard__Address ng-tns-c427-0" href="/residential/brochure/carrowbeg-westport-mayo/4532273">
#     Carrowbeg, Westport, Mayo
#    </a>
#    <app-mh-property-info-strip class="mt-2 ng-tns-c427-0 ng-star-inserted">
#     <!-- -->
#     <div class="PropertyInfoStrip ng-star-inserted">
#      <span class="PropertyInfoStrip__Detail PropertyInfoStrip__Detail--dark ng-star-inserted">
#       <app-mh-icon class="mr-1" icon="bed">
#        <div aria-hidden="true" class="MhIcon">
#         <svg>
#          <use xlink:href="../../../../assets/images/mh-icons.svg#bed">
#          </use>
#         </svg>
#        </div>
#       </app-mh-icon>
#       4 beds
#      </span>
#      <!-- -->
#      <span class="PropertyInfoStrip__Detail PropertyInfoStrip__Detail--dark ng-star-inserted">
#       <app-mh-icon class="mr-1" icon="bath">
#        <div aria-hidden="true" class="MhIcon">
#         <svg>
#          <use xlink:href="../../../../assets/images/mh-icons.svg#bath">
#          </use>
#         </svg>
#        </div>
#       </app-mh-icon>
#       3 baths
#      </span>
#      <!-- -->
#      <span class="PropertyInfoStrip__Detail PropertyInfoStrip__Detail--dark ng-star-inserted">
#       <app-mh-icon class="mr-1" icon="cube">
#        <div aria-hidden="true" class="MhIcon">
#         <svg>
#          <use xlink:href="../../../../assets/images/mh-icons.svg#cube">
#          </use>
#         </svg>
#        </div>
#       </app-mh-icon>
#       203m
#       <sup>
#        2
#       </sup>
#      </span>
#      <!-- -->
#      <!-- -->
#      <span class="PropertyInfoStrip__Detail PropertyInfoStrip__Detail--dark ng-star-inserted">
#       <img alt="Energy Rating" class="ng-failed-lazyloaded ng-lazyloaded" height="17" width="48"/>
#      </span>
#      <!-- -->
#      <span class="PropertyInfoStrip__Detail PropertyInfoStrip__Detail--dark ng-star-inserted">
#       <app-mh-icon class="mr-1" icon="home">
#        <div aria-hidden="true" class="MhIcon">
#         <svg>
#          <use xlink:href="../../../../assets/images/mh-icons.svg#home">
#          </use>
#         </svg>
#        </div>
#       </app-mh-icon>
#       Detached House
#      </span>
#      <!-- -->
#      <!-- -->
#     </div>
#     <!-- -->
#    </app-mh-property-info-strip>
#    <!-- -->
#   </div>
#   <div class="PropertyListingCard__Footer ng-tns-c427-0">
#    <!-- -->
#    <!-- -->
#    <!-- -->
#    <!-- -->
#    <!-- -->
#   </div>
#  </div>
#  <div class="PropertyListingCard__Sidebar ng-tns-c427-0 ng-star-inserted">
#   <div class="PropertyListingCard__Group MhHelper__Flex--centered ng-tns-c427-0 ng-star-inserted">
#    <a class="PropertyListingCard__GroupLink ng-tns-c427-0" href="/estate-agents/olivia-needham-property-sales-and-rentals-5963">
#     <img alt="Group Logo" class="PropertyListingCard__GroupLogo ng-tns-c427-0 ng-failed-lazyloaded ng-lazyloaded" height="160" offset="200" width="160"/>
#    </a>
#    <!-- -->
#   </div>
#   <!-- -->
#   <!-- -->
#   <div class="PropertyListingCard__Buttons ng-tns-c427-0">
#    <!-- -->
#    <a class="ng-tns-c427-0 ng-star-inserted" href="/residential/brochure/carrowbeg-westport-mayo/4532273">
#     <app-mh-button class="ng-tns-c427-0" color="blue" text="VIEW DETAILS">
#      <button class="MhFormElements__Button MhButton-- MhButton--blue MhButton--roundedCorners" id="">
#       <!-- -->
#       <!-- -->
#       <span>
#        VIEW DETAILS
#       </span>
#       <!-- -->
#      </button>
#     </app-mh-button>
#    </a>
#    <!-- -->
#   </div>
#   <div class="PropertyListingCard__ButtonsFooter MhHelper__Flex--spaced ng-tns-c427-0 ng-star-inserted">
#    <app-mh-button aria-hidden="true" class="ng-tns-c427-0" color="white" icon="map">
#     <button class="MhFormElements__Button MhButton-- MhButton--white MhButton--roundedCorners MhButton--noText" id="">
#      <app-mh-icon class="ng-star-inserted">
#       <div aria-hidden="true" class="MhIcon">
#        <svg>
#         <use xlink:href="../../../../assets/images/mh-icons.svg#map">
#         </use>
#        </svg>
#       </div>
#      </app-mh-icon>
#      <!-- -->
#      <!-- -->
#      <span>
#      </span>
#      <!-- -->
#     </button>
#    </app-mh-button>
#    <app-mh-button aria-hidden="true" class="ng-tns-c427-0 sel_save_icon_not_saved" color="white">
#     <button class="MhFormElements__Button MhButton-- MhButton--white MhButton--roundedCorners MhButton--noText" id="4532273">
#      <app-mh-icon class="ng-star-inserted">
#       <div aria-hidden="true" class="MhIcon">
#        <svg>
#         <use xlink:href="../../../../assets/images/mh-icons.svg#heart-open">
#         </use>
#        </svg>
#       </div>
#      </app-mh-icon>
#      <!-- -->
#      <!-- -->
#      <span>
#      </span>
#      <!-- -->
#     </button>
#    </app-mh-button>
#   </div>
#   <!-- -->
#   <!-- -->
#  </div>
#  <!-- -->
# </div>

# %%
price = listings.find(class_="PropertyListingCard__Price").text
print(price)
# Out:
# €400,000

# %%
listings = soup.findAll("div", class_="PropertyListingCard")
for listing in listings:
    entry = []
    price = listing.find(class_="PropertyListingCard__Price").text
    entry.append(price)
    address = listing.find(class_="PropertyListingCard__Address").text
    entry.append(address)
    print(entry)
# Out:
# ['€400,000 ', ' Carrowbeg, Westport, Mayo']
# ['€599,000 ', ' Formally Rosmoney Spa, Rosmoney, Westport, Co. Mayo']
# ['€125,000 ', ' 13 Ard Clar, Claremorris, Mayo']
# ['€70,000 ', ' Ballybeg Kincon, Ballina, Mayo']
# ['€950,000 ', ' Ballycurrin Demesne, Ower, Claremorris, Mayo']
# ['€285,000 ', ' Barnacarroll,Claremorris,Co Mayo,F12 Y5R5']
# ['€250,000 ', ' 1 Abbey Court,Killala Road,Ballina,Co Mayo,F26 Y8H1']
# ['€225,000 ', ' No. 46 Meadow Park, Westport Road, Castlebar, Mayo']
# ['€199,000 ', ' Culmore,Kilkelly,Co Mayo,F35 DD21']
# ['€145,000 ', ' Aghaloonteen, Lahardane, Ballina, Mayo']
# ['€425,000 ', ' Ballinamore,Kiltimagh,Co Mayo,F12ND29']
# ['€260,000 ', ' 37 St Marys Crescent, Westport, Mayo']
# ['€350,000 ', ' Ardagh, Ballina, Mayo']
# ['€120,000 ', ' 23 Carrowmore Meadows, Carrowmore, Knock, Mayo']
# ['€565,000 ', ' Derry Quay, Cross, Co Mayo, Cross, Mayo']
# ['€45,000 ', ' Ballinahalla, The Neale, Mayo']
# ['€40,000 ', ' Glanduff,Attymachugh,Foxford,Co Mayo,F26 DE61']
# ['€108,000 ', ' 7 Carrowkibbock Lower, Ballycastle, Mayo']
# ['€310,000 ', ' 3 The Woodlands,Mount Falcon,Ballina,Co Mayo,F26 V6R9']
# ['€79,000 ', ' Chapel St,Swinford,Co Mayo,F12 PY62']
# ['€55,000 ', ' Clossagh,Foxford,Co Mayo']

# %%
page = requests.get("https://www.myhome.ie/residential/mayo/property-for-sale?page=1") 
soup = BeautifulSoup(page.content, 'html.parser') 

listings = soup.findAll("div", class_="PropertyListingCard")

with open("week03_home.csv", mode='w', newline='') as home_file:
    home_writer = csv.writer(home_file,delimiter='\t', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    
    for listing in listings:
        entryList = []
        price=listing.find(class_="PropertyListingCard__Price").text
        entryList.append(price)
        address = listing.find(class_="PropertyListingCard__Address").text
        entryList.append(address)
        
        home_writer.writerow(entryList)
